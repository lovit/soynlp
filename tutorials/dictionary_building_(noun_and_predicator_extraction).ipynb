# %%
import math
import sys
sys.path.insert(0, '../')
import soynlp
print(soynlp.__version__)
# Out:
# 0.0.46

# %% [markdown]
# # Movie comment data

# %%
# movie comments
corpus_path = 'merged_comments.txt' # set your data path

# <idx, comment, rate>
with open(corpus_path, encoding='utf-8') as f:
    sentences = [doc.split('\t')[1] for doc in f]
    sentences = [sent for sent in sentences if sent]
print('num sentences = %d' % len(sentences))
# Out:
# num sentences = 294493

# %% [markdown]
# ## Noun Extraction

# %%
from soynlp.noun import LRNounExtractor_v2

noun_extractor = LRNounExtractor_v2(
    max_left_length=10, max_right_length=9,
    verbose=True, min_num_of_features=2,
    max_frequency_when_noun_is_eojeol=10,
    min_eojeol_frequency=2,
    extract_compound=True, extract_pos_feature=False
)

noun_scores = noun_extractor.train_extract(
    sentences,
    min_noun_score=0.3,
    min_noun_frequency=2,  # 추출되는 명사의 최소 빈도수
    min_eojeol_frequency=1,
    reset_lrgraph=False    # predicator extraction 을 위해서
)
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=1260, neg=1173, common=12
# [Noun Extractor] counting eojeols
# [EojeolCounter] n eojeol = 89170 from 294493 sents. mem=0.166 Gb
# [Noun Extractor] complete eojeol counter -> lr graph
# [Noun Extractor] has been trained. mem=0.297 Gb
# [Noun Extractor] batch prediction was completed for 28290 words
# [Noun Extractor] checked compounds. discovered 15 compounds
# [Noun Extractor] postprocessing detaching_features : 9458 -> 9335
# [Noun Extractor] postprocessing ignore_features : 9335 -> 9257
# [Noun Extractor] postprocessing ignore_NJ : 9257 -> 9131
# [Noun Extractor] 9131 nouns (15 compounds) with min frequency=2
# [Noun Extractor] flushing was done. mem=0.333 Gb
# [Noun Extractor] 68.04 % eojeols are covered

# %%
noun_scores['크리스토퍼']
# Out:
# NounScore(frequency=686, score=1.0)

# %%
for noun in sorted(noun_scores, key=lambda x:-math.sqrt(noun_scores[x].frequency) * noun_scores[x].score)[:30]:
    print('{}: {}'.format(noun, noun_scores[noun]))
# Out:
# 영화: NounScore(frequency=61200, score=0.7619601007166377)
# 정말: NounScore(frequency=18842, score=1.0)
# 너무: NounScore(frequency=13708, score=1.0)
# 진짜: NounScore(frequency=14504, score=0.9568345323741008)
# 최고: NounScore(frequency=12792, score=0.8792405063291139)
# 감독: NounScore(frequency=6591, score=1.0)
# 재미: NounScore(frequency=6048, score=0.9528061224489796)
# 생각: NounScore(frequency=5616, score=0.9793271179570329)
# 배우들: NounScore(frequency=5065, score=0.9925449000338868)
# ㅋㅋ: NounScore(frequency=4880, score=1.0)
# 감동: NounScore(frequency=4902, score=0.9840525328330206)
# 평점: NounScore(frequency=6226, score=0.8520084566596194)
# 마지막: NounScore(frequency=4508, score=1.0)
# 이런: NounScore(frequency=4861, score=0.904540379605508)
# 스토리: NounScore(frequency=4991, score=0.8579169175195666)
# 것: NounScore(frequency=3629, score=1.0)
# 그래: NounScore(frequency=3579, score=0.9900787861103005)
# 느낌: NounScore(frequency=3482, score=1.0)
# 내: NounScore(frequency=3778, score=0.9359138682389131)
# 대박: NounScore(frequency=3174, score=1.0)
# 솔직히: NounScore(frequency=3158, score=1.0)
# 사람: NounScore(frequency=3142, score=0.997948717948718)
# 처음: NounScore(frequency=3532, score=0.9375)
# 놀란: NounScore(frequency=3118, score=0.9966044142614601)
# 사람들: NounScore(frequency=3068, score=0.9974763406940063)
# 심형래: NounScore(frequency=2938, score=1.0)
# CG: NounScore(frequency=2907, score=0.994368840919756)
# 그리고: NounScore(frequency=2852, score=0.9985994397759104)
# 완전: NounScore(frequency=2760, score=1.0)
# ㅠㅠ: NounScore(frequency=2759, score=1.0)

# %% [markdown]
# ## Predicator Extraction

# %%
from soynlp.predicator import PredicatorExtractor

# prepare materials from noun extractor
noun_pos_features = noun_extractor._pos_features
nouns = {noun for noun in noun_scores}

# initiate
predicator_extractor = PredicatorExtractor(
    nouns = nouns,
    noun_pos_features = noun_pos_features, # "명사 + 조사/형용사" 어절을 걸러내기 위함
    extract_eomi=True,
    extract_stem=True,
    verbose=True
)

predicator_extractor.train(
    sentences,
    min_eojeol_frequency = 3
)

print('num stems (before stem extraction) = %d' % len(predicator_extractor._stems))
print('num eomis (before eomi extraction) = %d' % len(predicator_extractor._eomis))

predicators = predicator_extractor.extract(
    min_predicator_frequency=3, reset_lrgraph=True,
    # Eomi extractor
    min_num_of_features=2, min_eomi_score=0.3, min_eomi_frequency=1,
    # Stem extractor
    min_num_of_unique_R_char=10, min_entropy_of_R_char=0.5,
    min_entropy_of_R=1.5, min_stem_score=0.7, min_stem_frequency=5
)

print('num stems (after stem extraction) = %d' % len(predicator_extractor._stems))
print('num eomis (after eomi extraction) = %d' % len(predicator_extractor._eomis))
# Out:
# [Predicator Extractor] counting eojeols was done. 60208 eojeols, mem=0.333 Gb
# [Predicator Extractor] complete eojeol counter -> lr graph
# [Predicator Extractor] has been trained. mem=0.333 Gb
# num stems (before stem extraction) = 1248
# num eomis (before eomi extraction) = 1120
# [Eomi Extractor] batch prediction was completed for 5500 words
# [Eomi Extractor] eomi lemmatization with 714 candidates
# [Eomi Extractor] 1562 eomis extracted with min frequency = 1, min score = 0.3
# [Predicator Extractor] 1287 eomis have been extracted
# [Stem Extractor] Initializing was done with 1248 stems and 2407 eomisis
# [Stem Extractor] batch prediction for 4695 candidates
# [Stem Extractor] 37 stems, 18 surfacial stems, 13 removals
# [Predicator Extractor] 37 stems have been extracted
# [Predicator Extractor] lemma candidating was done. 64.558 % eojeols are covered
# [Predicator Extractor] 6474 predicators are extracted
# num stems (after stem extraction) = 1285
# num eomis (after eomi extraction) = 2407

# %%
frequency_sorted_predicators = sorted(predicators, key=lambda x: -predicators[x].frequency)

word_sets = [
    frequency_sorted_predicators[:50],
    frequency_sorted_predicators[-500:-400]
]

for word_set in word_sets:
    for word in word_set:
        lemmas = predicators[word]
        print('{}: {}'.format(word, lemmas))
    print('--' * 30)
# Out:
# 보고: Predicator(frequency=5899, lemma={('보', '고')})
# 내가: Predicator(frequency=3718, lemma={('내', '가'), ('낳', '아가')})
# 봤는데: Predicator(frequency=3560, lemma={('보', '았는데')})
# 하지만: Predicator(frequency=3507, lemma={('하', '지만')})
# 이건: Predicator(frequency=3414, lemma={('이', '건')})
# 있는: Predicator(frequency=2966, lemma={('있', '는'), ('이', 'ㅆ는')})
# 이렇게: Predicator(frequency=2891, lemma={('이렇', '게')})
# 없는: Predicator(frequency=2848, lemma={('없', '는'), ('이', '없는')})
# 보는: Predicator(frequency=2775, lemma={('보', '는')})
# 없다: Predicator(frequency=2686, lemma={('없', '다'), ('이', '없다')})
# 재밌게: Predicator(frequency=2573, lemma={('재밌', '게')})
# 하는: Predicator(frequency=2453, lemma={('하', '는')})
# 좋은: Predicator(frequency=2429, lemma={('좋', '은'), ('좋으', 'ㄴ')})
# 이게: Predicator(frequency=2391, lemma={('이', '게')})
# 내내: Predicator(frequency=2140, lemma={('낳', '아내'), ('내', '내')})
# 보세요: Predicator(frequency=2105, lemma={('보', '세요')})
# 보면: Predicator(frequency=2071, lemma={('보', '면')})
# 같다: Predicator(frequency=1847, lemma={('같', '다')})
# 같은: Predicator(frequency=1703, lemma={('같', '은')})
# 대한: Predicator(frequency=1691, lemma={('대하', 'ㄴ')})
# 만든: Predicator(frequency=1660, lemma={('만드', 'ㄴ')})
# 어떻게: Predicator(frequency=1632, lemma={('어떻', '게')})
# 하고: Predicator(frequency=1554, lemma={('하', '고')})
# 없고: Predicator(frequency=1515, lemma={('이', '없고'), ('없', '고')})
# 많은: Predicator(frequency=1497, lemma={('많', '은')})
# 봤다: Predicator(frequency=1458, lemma={('보', '았다')})
# 봤어요: Predicator(frequency=1392, lemma={('보', '았어요')})
# 다른: Predicator(frequency=1380, lemma={('다르', 'ㄴ')})
# 봐도: Predicator(frequency=1315, lemma={('보', '아도')})
# 만드는: Predicator(frequency=1295, lemma={('만드', '는')})
# 있다: Predicator(frequency=1269, lemma={('있', '다'), ('이', 'ㅆ다')})
# 재밌다: Predicator(frequency=1222, lemma={('재밌', '다')})
# 재밌어요: Predicator(frequency=1178, lemma={('재밌', '어요')})
# 않은: Predicator(frequency=1167, lemma={('않으', 'ㄴ'), ('않', '은')})
# 보면서: Predicator(frequency=1156, lemma={('보', '면서')})
# 끝나고: Predicator(frequency=1090, lemma={('끝나', '고')})
# 좋았다: Predicator(frequency=1084, lemma={('좋', '았다'), ('좋았', '다'), ('좋아', 'ㅆ다'), ('좋으', '았다'), ('좋앟', 'ㅆ다')})
# 않고: Predicator(frequency=1084, lemma={('않', '고')})
# 모르고: Predicator(frequency=1083, lemma={('모르', '고')})
# 싶다: Predicator(frequency=1053, lemma={('싶', '다')})
# 그렇게: Predicator(frequency=1048, lemma={('그렇', '게')})
# 있고: Predicator(frequency=1027, lemma={('이', 'ㅆ고'), ('있', '고')})
# 나도: Predicator(frequency=1027, lemma={('나', '도'), ('낳', '도')})
# 다들: Predicator(frequency=1003, lemma={('닿', '들')})
# 아니라: Predicator(frequency=996, lemma={('아니', '라')})
# 싶은: Predicator(frequency=947, lemma={('싶', '은')})
# 보다: Predicator(frequency=947, lemma={('보', '다')})
# 같아요: Predicator(frequency=927, lemma={('같', '아요')})
# 없이: Predicator(frequency=889, lemma={('없', '이')})
# 있지만: Predicator(frequency=869, lemma={('있', '지만'), ('이', 'ㅆ지만')})
# ------------------------------------------------------------
# 뿌리고: Predicator(frequency=4, lemma={('뿌리', '고')})
# 치워라: Predicator(frequency=4, lemma={('치', '워라'), ('치우', '어라')})
# 걸렸습니다: Predicator(frequency=4, lemma={('걸리', '었습니다')})
# 하라: Predicator(frequency=4, lemma={('하', '라')})
# 안본건: Predicator(frequency=4, lemma={('안보', 'ㄴ건')})
# 안좋았던: Predicator(frequency=4, lemma={('안좋', '았던')})
# 된통: Predicator(frequency=4, lemma={('되', 'ㄴ통')})
# 죽어가는데: Predicator(frequency=4, lemma={('죽', '어가는데'), ('죽이', '어가는데')})
# 죽은거: Predicator(frequency=4, lemma={('죽', '은거')})
# 되겠군: Predicator(frequency=4, lemma={('되', '겠군')})
# 다니지: Predicator(frequency=4, lemma={('다니', '지')})
# 다르죠: Predicator(frequency=4, lemma={('다르', '죠')})
# 어쩌라는: Predicator(frequency=4, lemma={('어쩌', '라는')})
# 대리고: Predicator(frequency=4, lemma={('대', '리고'), ('닿', '아리고')})
# 싸웠음: Predicator(frequency=4, lemma={('싸', '웠음'), ('쓰', '아웠음'), ('쌓', '웠음'), ('싸우', '었음')})
# 자빠진: Predicator(frequency=4, lemma={('자', '빠진')})
# 안좋은건: Predicator(frequency=4, lemma={('안좋', '은건')})
# 힘들었을텐데: Predicator(frequency=4, lemma={('힘들', '었을텐데')})
# 올렸으면: Predicator(frequency=4, lemma={('올리', '었으면')})
# 무서웟음: Predicator(frequency=4, lemma={('무섭', '엇음')})
# 얻었음: Predicator(frequency=4, lemma={('얻', '었음'), ('이', '얻었음')})
# 잘하십니다: Predicator(frequency=4, lemma={('잘하', '십니다')})
# 불러서: Predicator(frequency=4, lemma={('불리', '어서'), ('불', '러서'), ('부르', '어서')})
# 안했다면: Predicator(frequency=4, lemma={('안하', '았다면')})
# 잼없었어요: Predicator(frequency=4, lemma={('잼이', '없었어요')})
# 없지만요: Predicator(frequency=4, lemma={('없', '지만요'), ('이', '없지만요')})
# 홀린다: Predicator(frequency=4, lemma={('홀리', 'ㄴ다')})
# 차는: Predicator(frequency=4, lemma={('차', '는')})
# 보다시피: Predicator(frequency=4, lemma={('보', '다시피')})
# 만들다만: Predicator(frequency=4, lemma={('만들', '다만')})
# 드러워서: Predicator(frequency=4, lemma={('드리', '어워서')})
# 무서워도: Predicator(frequency=4, lemma={('무섭', '어도')})
# 믿거나: Predicator(frequency=4, lemma={('믿', '거나')})
# 걸렸는데: Predicator(frequency=4, lemma={('걸리', '었는데')})
# 막으려는: Predicator(frequency=4, lemma={('막', '으려는')})
# 싸도: Predicator(frequency=4, lemma={('싸', '도'), ('쓰', '아도'), ('쌓', '도')})
# 잘하지: Predicator(frequency=4, lemma={('잘하', '지')})
# 꿰는: Predicator(frequency=4, lemma={('꿰', '는')})
# 넣어놓고: Predicator(frequency=4, lemma={('넣', '어놓고')})
# 무섭단: Predicator(frequency=4, lemma={('무섭', '단')})
# 즐기게: Predicator(frequency=4, lemma={('즐기', '게')})
# 찾아보며: Predicator(frequency=4, lemma={('찾아보', '며')})
# 갑중에: Predicator(frequency=4, lemma={('가', 'ㅂ중에')})
# 해놓은: Predicator(frequency=4, lemma={('하', '아놓은')})
# 읽으니: Predicator(frequency=4, lemma={('읽', '으니')})
# 무서워여: Predicator(frequency=4, lemma={('무섭', '어여')})
# 물릴: Predicator(frequency=4, lemma={('물', '릴'), ('물리', 'ㄹ')})
# 좋아할지: Predicator(frequency=4, lemma={('좋아하', 'ㄹ지')})
# 켜고: Predicator(frequency=4, lemma={('켜', '고')})
# 일어나느냐: Predicator(frequency=4, lemma={('일어나', '느냐')})
# 꿰뚫는: Predicator(frequency=4, lemma={('꿰뚫', '는')})
# 맞추니: Predicator(frequency=4, lemma={('맞추', '니')})
# 만났으면: Predicator(frequency=4, lemma={('만나', 'ㅆ으면')})
# 되야한다: Predicator(frequency=4, lemma={('되', '야한다')})
# 하기위해: Predicator(frequency=4, lemma={('하', '기위해')})
# 색달라서: Predicator(frequency=4, lemma={('색다르', '아서')})
# 아니든: Predicator(frequency=4, lemma={('아니', '든')})
# 견디기: Predicator(frequency=4, lemma={('견디', '기')})
# 재밌으니: Predicator(frequency=4, lemma={('재밌', '으니')})
# 감을: Predicator(frequency=4, lemma={('감', '을')})
# 먹던: Predicator(frequency=4, lemma={('먹', '던')})
# 할꺼면: Predicator(frequency=4, lemma={('하', 'ㄹ꺼면')})
# 다룬다: Predicator(frequency=4, lemma={('다루', 'ㄴ다')})
# 잇을까: Predicator(frequency=4, lemma={('잇', '을까')})
# 업음: Predicator(frequency=4, lemma={('이', '업음'), ('업', '음')})
# 치자면: Predicator(frequency=4, lemma={('치', '자면')})
# 꼬다가: Predicator(frequency=4, lemma={('꼬', '다가')})
# 더러워요: Predicator(frequency=4, lemma={('더럽', '어요')})
# 있게하는: Predicator(frequency=4, lemma={('이', 'ㅆ게하는'), ('있', '게하는')})
# 돋보이네요: Predicator(frequency=4, lemma={('돋보이', '네요')})
# 불러온: Predicator(frequency=4, lemma={('불', '러온'), ('부르', '어온'), ('불리', '어온')})
# 되야할: Predicator(frequency=4, lemma={('되', '야할')})
# 망쳤네: Predicator(frequency=4, lemma={('망치', '었네')})
# 못한거다: Predicator(frequency=4, lemma={('못하', 'ㄴ거다')})
# 오니까: Predicator(frequency=4, lemma={('오', '니까')})
# 치우쳐서: Predicator(frequency=4, lemma={('치우치', '어서')})
# 많더라구요: Predicator(frequency=4, lemma={('많', '더라구요')})
# 안했어: Predicator(frequency=4, lemma={('안하', '았어')})
# 물린: Predicator(frequency=4, lemma={('물리', 'ㄴ'), ('물', '린')})
# 뭉친: Predicator(frequency=4, lemma={('뭉치', 'ㄴ')})
# 찾아보는데: Predicator(frequency=4, lemma={('찾아보', '는데')})
# 만들며: Predicator(frequency=4, lemma={('만들', '며'), ('만드', 'ㄹ며')})
# 끝내면: Predicator(frequency=4, lemma={('끝내', '면')})
# 먹히는: Predicator(frequency=4, lemma={('먹히', '는')})
# 드물게: Predicator(frequency=4, lemma={('드물', '게')})
# 당당하게: Predicator(frequency=4, lemma={('당당하', '게')})
# 깨기: Predicator(frequency=4, lemma={('깨', '기')})
# 튀어나오고: Predicator(frequency=4, lemma={('튀', '어나오고'), ('튀어나오', '고')})
# 갈리고: Predicator(frequency=4, lemma={('갈', '리고'), ('가', 'ㄹ리고')})
# 놀랐지만: Predicator(frequency=4, lemma={('놀', '랐지만'), ('놀라', 'ㅆ지만')})
# 더하는: Predicator(frequency=4, lemma={('더하', '는')})
# 아니라구: Predicator(frequency=4, lemma={('아니', '라구')})
# 말듯: Predicator(frequency=4, lemma={('말', '듯')})
# 잘나온: Predicator(frequency=4, lemma={('잘나', '온')})
# 계시다면: Predicator(frequency=4, lemma={('계시', '다면')})
# 풀려고: Predicator(frequency=4, lemma={('푸', 'ㄹ려고'), ('풀', '려고'), ('풀리', '어고')})
# 늘어놓고: Predicator(frequency=4, lemma={('늘어놓', '고'), ('늘', '어놓고')})
# 들림: Predicator(frequency=4, lemma={('들', '림')})
# 들어가게: Predicator(frequency=4, lemma={('들이', '어가게'), ('들어가', '게'), ('들', '어가게'), ('듣', '어가게')})
# 좋았으며: Predicator(frequency=4, lemma={('좋', '았으며'), ('좋아', 'ㅆ으며'), ('좋앟', 'ㅆ으며'), ('좋으', '았으며'), ('좋았', '으며')})
# ------------------------------------------------------------

# %% [markdown]
# # Chat text

# %% [markdown]
# ## Noun Extraction

# %%
import pickle
from soynlp.utils import LRGraph

# build noun extractor from {l:{r:count}} dict
with open('../tmp/lrgraph_dict_for_nounextraction.pkl', 'rb') as f:
    lrgraph = LRGraph(pickle.load(f))

chat_noun_extractor = LRNounExtractor_v2(
    extract_pos_feature=True
)

chat_noun_extractor.lrgraph = lrgraph
chat_noun_extractor._num_of_eojeols = lrgraph.to_EojeolCounter()._count_sum
# Out:
# [Noun Extractor] use default predictors
# [Noun Extractor] num features: pos=1260, neg=1173, common=12

# %%
chat_noun_scores = chat_noun_extractor.extract(
    min_noun_score=0.3,
    min_noun_frequency=2,  # 추출되는 명사의 최소 빈도수
    reset_lrgraph=False    # predicator extraction 을 위해서
)
# Out:
# [Noun Extractor] extract and append pos features
# [Noun Extractor] batch prediction for extracting pos feature
# [Noun Extractor] batch prediction was completed for 167504 words
# [Noun Extractor] features appended. pos=1260 -> 1260, neg=1173 -> 1173, common=12 -> 12
# [Noun Extractor] 0 pos features were extracted
# [Noun Extractor] batch prediction was completed for 167504 words
# [Noun Extractor] checked compounds. discovered 13 compounds
# [Noun Extractor] postprocessing detaching_features : 58046 -> 56981
# [Noun Extractor] postprocessing ignore_features : 56981 -> 56867
# [Noun Extractor] postprocessing ignore_NJ : 56867 -> 55706
# [Noun Extractor] 55706 nouns (13 compounds) with min frequency=2
# [Noun Extractor] flushing was done. mem=1.783 Gb
# [Noun Extractor] 58.14 % eojeols are covered

# %%
for word in '여부 서가앤쿡 맘스터치 신라스테이 설입 '.split():
    print('{}: {}'.format(word, chat_noun_scores.get(word, None)))
# Out:
# 여부: NounScore(frequency=4831, score=0.7579092159559835)
# 서가앤쿡: NounScore(frequency=121, score=1.0)
# 맘스터치: NounScore(frequency=336, score=0.9178082191780822)
# 신라스테이: NounScore(frequency=11, score=1.0)
# 설입: NounScore(frequency=71, score=1.0)

# %%
word_sets = [
    sorted(chat_noun_scores, key=lambda x:-chat_noun_scores[x].frequency)[:50],
    sorted(chat_noun_scores, key=lambda x:-chat_noun_scores[x].frequency)[3000:3050]
]
for word_set in word_sets:
    for noun in word_set:
        print('{}: {}'.format(noun, chat_noun_scores[noun]))
    print('--' * 30)
# Out:
# 내: NounScore(frequency=253502, score=0.9581029653240607)
# 그래: NounScore(frequency=219531, score=0.8884650675055709)
# 오늘: NounScore(frequency=202989, score=0.9519450800915332)
# 진짜: NounScore(frequency=184587, score=0.8989955357142857)
# 근데: NounScore(frequency=173788, score=0.8535127055306427)
# 너무: NounScore(frequency=157721, score=0.9843899330997132)
# 그냥: NounScore(frequency=147720, score=0.7358490566037735)
# 오빠: NounScore(frequency=146246, score=0.9886392234405896)
# 지금: NounScore(frequency=140182, score=0.8701720220707563)
# 그럼: NounScore(frequency=132727, score=0.8043704474505723)
# 사랑: NounScore(frequency=121283, score=0.9992462852630823)
# 내일: NounScore(frequency=101316, score=0.7156619678401926)
# 많이: NounScore(frequency=100460, score=0.8667058132706987)
# 응응: NounScore(frequency=85628, score=1.0)
# 우리: NounScore(frequency=84382, score=0.9788417943257539)
# 너: NounScore(frequency=78604, score=0.9711176803572552)
# 미안: NounScore(frequency=73317, score=0.9991863447421951)
# 헤헤: NounScore(frequency=71407, score=1.0)
# 안: NounScore(frequency=66868, score=0.38802360452742574)
# 아직: NounScore(frequency=65260, score=0.9390134529147982)
# 여보: NounScore(frequency=59828, score=0.8183999494853823)
# 집: NounScore(frequency=59661, score=0.9332257044421883)
# 아니야: NounScore(frequency=56098, score=0.9747235387045814)
# N시: NounScore(frequency=52528, score=0.62901682705836)
# 그거: NounScore(frequency=52374, score=0.7145943610240899)
# 어제: NounScore(frequency=50444, score=0.9713145422798702)
# 생각: NounScore(frequency=49885, score=0.9846913128912854)
# 아냐: NounScore(frequency=44511, score=0.5486725663716814)
# 계속: NounScore(frequency=42252, score=0.8161490683229814)
# 이거: NounScore(frequency=42248, score=0.4708261120739457)
# 엄청: NounScore(frequency=41633, score=0.8320610687022901)
# 바: NounScore(frequency=40726, score=0.8274321072533517)
# 정말: NounScore(frequency=38508, score=0.994475138121547)
# 엄마: NounScore(frequency=37122, score=0.9857083100948132)
# 사람: NounScore(frequency=36428, score=0.9862014587029371)
# 일단: NounScore(frequency=36192, score=0.7647058823529411)
# 몰라: NounScore(frequency=33995, score=0.6929069956175945)
# 자기야: NounScore(frequency=33362, score=0.9865771812080537)
# N분: NounScore(frequency=33043, score=0.9884685151593677)
# 완전: NounScore(frequency=33030, score=1.0)
# 그런: NounScore(frequency=32171, score=0.5721669466339321)
# 아까: NounScore(frequency=31241, score=0.4425740464521628)
# 이따: NounScore(frequency=30570, score=0.66867705804026)
# 먹고: NounScore(frequency=28337, score=0.6160970935803258)
# 말: NounScore(frequency=27735, score=0.548855608929076)
# 언제: NounScore(frequency=27686, score=0.589914505144182)
# 뭐: NounScore(frequency=27612, score=0.32054821534214156)
# 뭐야: NounScore(frequency=27138, score=0.9054054054054054)
# 무슨: NounScore(frequency=26892, score=1.0)
# 나랑: NounScore(frequency=26433, score=0.6682464454976303)
# ------------------------------------------------------------
# 설정: NounScore(frequency=512, score=1.0)
# 드립: NounScore(frequency=512, score=1.0)
# 팩: NounScore(frequency=512, score=1.0)
# 들어갈때: NounScore(frequency=511, score=1.0)
# 볼꺼야: NounScore(frequency=511, score=1.0)
# 친절: NounScore(frequency=511, score=1.0)
# 고터: NounScore(frequency=511, score=0.9545454545454546)
# 소파: NounScore(frequency=511, score=1.0)
# 키야: NounScore(frequency=511, score=1.0)
# 됴: NounScore(frequency=511, score=0.562874251497006)
# 경기도: NounScore(frequency=510, score=1.0)
# 합격: NounScore(frequency=510, score=0.8901960784313725)
# 파티: NounScore(frequency=510, score=0.8248847926267281)
# 봄봄: NounScore(frequency=510, score=1.0)
# 중학교때: NounScore(frequency=509, score=1.0)
# 없으니깐: NounScore(frequency=509, score=1.0)
# 서영이: NounScore(frequency=509, score=1.0)
# 버거킹: NounScore(frequency=509, score=1.0)
# 잘햇네: NounScore(frequency=509, score=0.30434782608695654)
# 밥맛: NounScore(frequency=509, score=1.0)
# 밴드: NounScore(frequency=509, score=0.7040816326530612)
# 한창: NounScore(frequency=509, score=1.0)
# 해쪄: NounScore(frequency=509, score=0.9016393442622951)
# 주인공: NounScore(frequency=508, score=1.0)
# 차로: NounScore(frequency=508, score=1.0)
# 깼다: NounScore(frequency=508, score=0.7014925373134329)
# N야: NounScore(frequency=508, score=1.0)
# 지영이: NounScore(frequency=507, score=1.0)
# 안나네: NounScore(frequency=507, score=0.9168173598553345)
# 완성: NounScore(frequency=507, score=0.9815668202764977)
# 재수: NounScore(frequency=507, score=1.0)
# 가긴: NounScore(frequency=507, score=1.0)
# 모의고사: NounScore(frequency=506, score=0.9368421052631579)
# 비밀번호: NounScore(frequency=506, score=1.0)
# 목도리: NounScore(frequency=506, score=1.0)
# 에라이: NounScore(frequency=506, score=1.0)
# 쉴때: NounScore(frequency=506, score=1.0)
# N천: NounScore(frequency=506, score=0.75)
# 얘기하구: NounScore(frequency=505, score=1.0)
# 그생각: NounScore(frequency=505, score=1.0)
# 이성: NounScore(frequency=505, score=0.9840848806366048)
# 세명: NounScore(frequency=505, score=0.9797979797979798)
# 인누: NounScore(frequency=505, score=0.9)
# 저녁때: NounScore(frequency=504, score=0.8837209302325582)
# 아야: NounScore(frequency=504, score=0.5206611570247934)
# 해놔: NounScore(frequency=504, score=0.31004366812227074)
# 집인데: NounScore(frequency=503, score=0.7872340425531915)
# 진도: NounScore(frequency=503, score=1.0)
# 확률: NounScore(frequency=503, score=1.0)
# 욕을: NounScore(frequency=503, score=1.0)
# ------------------------------------------------------------

# %% [markdown]
# **TODO**
# 1. N is N+J postprocessing 에서 길이가 2 이하인 단어를 pass 하다보니 "욕 + 을" 이 명사로 추출. 두 글자의 명사는 각 글자가 명사, 조사인 경우가 많아서 이는 postprocessing 으로 처리하기 어려움

# %% [markdown]
# ## Predicator Extraction

# %%
from soynlp.predicator import PredicatorExtractor

# prepare materials from noun extractor
chat_noun_pos_features = chat_noun_extractor._pos_features
chat_nouns = {noun for noun in chat_noun_scores}
chat_lrgraph = LRGraph(chat_noun_extractor.lrgraph._lr)

# initiate
chat_predicator_extractor = PredicatorExtractor(
    nouns = chat_nouns,
    noun_pos_features = chat_noun_pos_features, # "명사 + 조사/형용사" 어절을 걸러내기 위함
    extract_eomi=True,
    extract_stem=True,
    verbose=True
)

chat_predicator_extractor.train(
    #sentences,
    chat_lrgraph, # sentence 대신 LRGraph 를 넣어도 됨
    min_eojeol_frequency = 3
)

print('num stems (before stem extraction) = %d' % len(chat_predicator_extractor._stems))
print('num eomis (before eomi extraction) = %d' % len(chat_predicator_extractor._eomis))

chat_predicators = chat_predicator_extractor.extract(
    min_predicator_frequency=5, reset_lrgraph=True,
    # Eomi extractor
    min_num_of_features=4, min_eomi_score=0.3, min_eomi_frequency=10,
    # Stem extractor
    min_num_of_unique_R_char=5, min_entropy_of_R_char=0.5,
    min_entropy_of_R=1.5, min_stem_score=0.7, min_stem_frequency=5
)

print('num stems (after stem extraction) = %d' % len(chat_predicator_extractor._stems))
print('num eomis (after eomi extraction) = %d' % len(chat_predicator_extractor._eomis))
# Out:
# num stems (before stem extraction) = 1248
# num eomis (before eomi extraction) = 1120
# [Eomi Extractor] batch prediction was completed for 103217 words
# [Eomi Extractor] eomi lemmatization with 5460 candidates
# [Eomi Extractor] 11511 eomis extracted with min frequency = 10, min score = 0.3
# [Predicator Extractor] 10994 eomis have been extracted
# [Stem Extractor] Initializing was done with 1248 stems and 12114 eomisis
# [Stem Extractor] batch prediction for 58689 candidates
# [Stem Extractor] 2558 stems, 1584 surfacial stems, 2888 removals
# [Predicator Extractor] 2528 stems have been extracted
# [Predicator Extractor] lemma candidating was done. 70.088 % eojeols are covered
# [Predicator Extractor] 75327 predicators are extracted
# num stems (after stem extraction) = 3776
# num eomis (after eomi extraction) = 12114

# %%
frequency_sorted_chat_predicators = sorted(chat_predicators, key=lambda x: -chat_predicators[x].frequency)

word_sets = [
    frequency_sorted_chat_predicators[:50],
    frequency_sorted_chat_predicators[10400:10500]
]

for word_set in word_sets:
    for word in word_set:
        lemmas = chat_predicators[word]
        print('{}: {}'.format(word, lemmas))
    print('--' * 30)
# Out:
# 내가: Predicator(frequency=251537, lemma={('내', '가'), ('내그', '아'), ('낳', '아가')})
# 이제: Predicator(frequency=170348, lemma={('이', '제')})
# 나도: Predicator(frequency=150243, lemma={('나', '도'), ('낳', '도')})
# 나는: Predicator(frequency=96965, lemma={('나', '는'), ('낳', '는')})
# 자기: Predicator(frequency=88198, lemma={('자', '기')})
# 같이: Predicator(frequency=61417, lemma={('같', '이')})
# 다시: Predicator(frequency=43174, lemma={('닿', '시')})
# 그렇게: Predicator(frequency=41940, lemma={('그렇', '게')})
# 하고: Predicator(frequency=40197, lemma={('하', '고')})
# 나두: Predicator(frequency=40086, lemma={('낳', '두'), ('나', '두')})
# 너가: Predicator(frequency=38115, lemma={('너그', '아'), ('넣', '가')})
# 그리고: Predicator(frequency=34275, lemma={('그리', '고')})
# 빨리: Predicator(frequency=33545, lemma={('빨', '리')})
# 좋아: Predicator(frequency=30761, lemma={('좋', '아')})
# 어떻게: Predicator(frequency=29312, lemma={('어떻', '게')})
# 있어: Predicator(frequency=29049, lemma={('이', 'ㅆ어'), ('있', '어')})
# 이렇게: Predicator(frequency=26173, lemma={('이렇', '게')})
# 맞아: Predicator(frequency=25697, lemma={('맞', '아')})
# 보고: Predicator(frequency=25504, lemma={('보', '고')})
# 갑자기: Predicator(frequency=24793, lemma={('가', 'ㅂ자기')})
# 자기가: Predicator(frequency=24372, lemma={('자', '기가')})
# 그러면: Predicator(frequency=23537, lemma={('그렇', '면'), ('그르', '어면'), ('그러', '면'), ('그리', '어면')})
# 없어: Predicator(frequency=23525, lemma={('없', '어'), ('이', '없어')})
# 일찍: Predicator(frequency=22957, lemma={('일', '찍'), ('이', 'ㄹ찍')})
# 하면: Predicator(frequency=22670, lemma={('하', '면')})
# 잘자: Predicator(frequency=21665, lemma={('잘', '자'), ('자', 'ㄹ자'), ('잘즈', '아')})
# 안돼: Predicator(frequency=21330, lemma={('안', '돼')})
# 고마워: Predicator(frequency=20756, lemma={('고맙', '어')})
# 괜찮아: Predicator(frequency=20253, lemma={('괜찮', '아')})
# 오오: Predicator(frequency=18240, lemma={('오', '오')})
# 해서: Predicator(frequency=17518, lemma={('하', '아서')})
# 하나: Predicator(frequency=16701, lemma={('하', '나')})
# 아니면: Predicator(frequency=16685, lemma={('아니', '면')})
# 귀여워: Predicator(frequency=16531, lemma={('귀엽', '어')})
# 이미: Predicator(frequency=16479, lemma={('이', '미')})
# 알겠어: Predicator(frequency=15195, lemma={('알', '겠어'), ('알겋', '었어')})
# 이게: Predicator(frequency=15063, lemma={('이', '게')})
# 씻고: Predicator(frequency=15057, lemma={('씻', '고')})
# 여기: Predicator(frequency=15053, lemma={('이', '어기')})
# 너도: Predicator(frequency=14958, lemma={('넣', '도')})
# 누가: Predicator(frequency=14798, lemma={('누', '가')})
# 했는데: Predicator(frequency=14530, lemma={('하', '았는데')})
# 같아: Predicator(frequency=14168, lemma={('같', '아')})
# 자기는: Predicator(frequency=13446, lemma={('자', '기는')})
# 아니고: Predicator(frequency=13349, lemma={('아니', '고')})
# 먹어: Predicator(frequency=13159, lemma={('먹', '어'), ('먹이', '어')})
# 이런: Predicator(frequency=12979, lemma={('이렇', 'ㄴ'), ('이러', 'ㄴ')})
# 이건: Predicator(frequency=12633, lemma={('이', '건')})
# 있는데: Predicator(frequency=12308, lemma={('있', '는데'), ('이', 'ㅆ는데')})
# 늦게: Predicator(frequency=12301, lemma={('늦', '게')})
# ------------------------------------------------------------
# 반해서: Predicator(frequency=74, lemma={('반하', '아서')})
# 않으니깐: Predicator(frequency=74, lemma={('않', '으니깐')})
# 느끼기엔: Predicator(frequency=74, lemma={('느끼', '기엔')})
# 사먹으면: Predicator(frequency=74, lemma={('사먹', '으면'), ('사미', '억으면'), ('사므', '억으면')})
# 앉는: Predicator(frequency=74, lemma={('앉', '는')})
# 잘되는: Predicator(frequency=74, lemma={('잘되', '는')})
# 안닮았어: Predicator(frequency=74, lemma={('안닮', '았어')})
# 톡보내고: Predicator(frequency=74, lemma={('톡보낳', '아고'), ('톡보내', '고')})
# 있단다: Predicator(frequency=74, lemma={('이', 'ㅆ단다'), ('있', '단다'), ('있닿', 'ㄴ다')})
# 친하면: Predicator(frequency=74, lemma={('친하', '면')})
# 끄면: Predicator(frequency=74, lemma={('끄', '면')})
# 서고: Predicator(frequency=74, lemma={('서', '고')})
# 안아주면서: Predicator(frequency=74, lemma={('안', '아주면서'), ('안으', '아주면서')})
# 덥넹: Predicator(frequency=74, lemma={('덥', '넹')})
# 고마워욤: Predicator(frequency=74, lemma={('고맙', '어욤')})
# 매고: Predicator(frequency=74, lemma={('매', '고')})
# 잘해보자: Predicator(frequency=74, lemma={('잘하', '아보자')})
# 가지만: Predicator(frequency=74, lemma={('가', '지만')})
# 나아용: Predicator(frequency=74, lemma={('낳', '아용'), ('나', '아용'), ('낫', '아용'), ('나으', '아용')})
# 이봐요: Predicator(frequency=74, lemma={('이', '봐요')})
# 하라며: Predicator(frequency=74, lemma={('하', '라며')})
# 해봐도: Predicator(frequency=74, lemma={('해보', '아도')})
# 사기로: Predicator(frequency=74, lemma={('사', '기로')})
# 잘잣니: Predicator(frequency=74, lemma={('잘즈', '앗니')})
# 댄다: Predicator(frequency=74, lemma={('닿', '안다'), ('대', 'ㄴ다')})
# 집이죠: Predicator(frequency=74, lemma={('집이', '죠')})
# 믿을께: Predicator(frequency=74, lemma={('믿', '을께')})
# 물어봐야: Predicator(frequency=74, lemma={('물어보', '아야'), ('묻', '어봐야'), ('물', '어봐야')})
# 놀라게: Predicator(frequency=74, lemma={('놀라', '게'), ('놀랗', '게')})
# 왔냐: Predicator(frequency=74, lemma={('오', '았냐')})
# 왔냐고: Predicator(frequency=74, lemma={('오', '았냐고')})
# 맛있넹: Predicator(frequency=74, lemma={('맛있', '넹'), ('맛이', 'ㅆ넹')})
# 그러시군요: Predicator(frequency=74, lemma={('그르', '어시군요'), ('그러', '시군요'), ('그렇', '시군요'), ('그리', '어시군요')})
# 가야한다고: Predicator(frequency=74, lemma={('가', '야한다고')})
# 말해야겠다: Predicator(frequency=74, lemma={('말해', '야겠다'), ('말햇', '야겠다'), ('말하', '아야겠다'), ('말핳', '아야겠다')})
# 몰고: Predicator(frequency=74, lemma={('몰', '고')})
# 배곺: Predicator(frequency=74, lemma={('배', '곺')})
# 느꼈던: Predicator(frequency=73, lemma={('느끼', '었던')})
# 꾸는: Predicator(frequency=73, lemma={('꾸', '는')})
# 안자넹: Predicator(frequency=73, lemma={('안', '자넹'), ('안자', '넹'), ('안잫', '넹'), ('안즈', '아넹')})
# 먹엇징: Predicator(frequency=73, lemma={('먹이', '엇징'), ('먹', '엇징')})
# 하구있어요: Predicator(frequency=73, lemma={('하', '구있어요')})
# 그러네용: Predicator(frequency=73, lemma={('그르', '어네용'), ('그렇', '네용'), ('그러', '네용'), ('그리', '어네용')})
# 해야쥐: Predicator(frequency=73, lemma={('하', '아야쥐')})
# 안먹어봄: Predicator(frequency=73, lemma={('안먹', '어봄')})
# 그랬으면서: Predicator(frequency=73, lemma={('그렇', '았으면서')})
# 믿어서: Predicator(frequency=73, lemma={('믿', '어서')})
# 안받게: Predicator(frequency=73, lemma={('안받', '게')})
# 듣는건: Predicator(frequency=73, lemma={('듣', '는건')})
# 붓기: Predicator(frequency=73, lemma={('붓', '기')})
# 원하고: Predicator(frequency=73, lemma={('원하', '고')})
# 흘려: Predicator(frequency=73, lemma={('흘리', '어')})
# 술안먹고: Predicator(frequency=73, lemma={('술안므', '억고'), ('술안미', '억고'), ('술안먹', '고')})
# 너같이: Predicator(frequency=73, lemma={('너같', '이')})
# 바보같다: Predicator(frequency=73, lemma={('바보같', '다')})
# 모햅: Predicator(frequency=73, lemma={('모하', '압'), ('모핳', '압')})
# 잘모르겠다: Predicator(frequency=73, lemma={('잘모르', '겠다')})
# 띵해: Predicator(frequency=73, lemma={('띵하', '아'), ('띵핳', '아')})
# 누워땅: Predicator(frequency=73, lemma={('눕', '어땅')})
# 다하지: Predicator(frequency=73, lemma={('다하', '지')})
# 찌고: Predicator(frequency=73, lemma={('찌', '고')})
# 봤고: Predicator(frequency=73, lemma={('보', '았고')})
# 없는가: Predicator(frequency=73, lemma={('이', '없는가'), ('없', '는가')})
# 챙겨갈게: Predicator(frequency=73, lemma={('챙겨그', '알게'), ('챙겨갛', 'ㄹ게'), ('챙겨가', 'ㄹ게')})
# 올리는거: Predicator(frequency=73, lemma={('올리', '는거')})
# 그러지말라고: Predicator(frequency=73, lemma={('그러', '지말라고'), ('그르', '어지말라고'), ('그리', '어지말라고'), ('그렇', '지말라고')})
# 잘자랏: Predicator(frequency=73, lemma={('잘즈', '아랏'), ('잘자', '랏'), ('잘잫', '랏')})
# 피지: Predicator(frequency=73, lemma={('피', '지')})
# 되겠구나: Predicator(frequency=73, lemma={('되', '겠구나')})
# 맘에드는데: Predicator(frequency=73, lemma={('맘에드', '는데')})
# 괜찮아졋어: Predicator(frequency=73, lemma={('괜찮', '아졋어')})
# 줫는데: Predicator(frequency=73, lemma={('주', '엇는데')})
# 되냐구: Predicator(frequency=73, lemma={('되', '냐구')})
# 밖이라: Predicator(frequency=73, lemma={('밖이', '라')})
# 말기: Predicator(frequency=73, lemma={('말', '기')})
# 이렇지: Predicator(frequency=73, lemma={('이렇', '지')})
# 남기면: Predicator(frequency=73, lemma={('남기', '면')})
# 와주면: Predicator(frequency=73, lemma={('오', '아주면')})
# 보구있어: Predicator(frequency=73, lemma={('보', '구있어')})
# 잘게영: Predicator(frequency=73, lemma={('잘', '게영'), ('자', 'ㄹ게영')})
# 너냐: Predicator(frequency=73, lemma={('넣', '냐')})
# 있는거같은데: Predicator(frequency=73, lemma={('이', 'ㅆ는거같은데'), ('있', '는거같은데')})
# 기쁘고: Predicator(frequency=73, lemma={('기쁘', '고')})
# 쉬는거지: Predicator(frequency=73, lemma={('쉬', '는거지')})
# 치는게: Predicator(frequency=73, lemma={('치', '는게')})
# 바쁘죠: Predicator(frequency=73, lemma={('바쁘', '죠')})
# 넘겨서: Predicator(frequency=73, lemma={('넘기', '어서')})
# 안들림: Predicator(frequency=73, lemma={('안드', 'ㄹ림')})
# 보려구요: Predicator(frequency=73, lemma={('보', '려구요')})
# 나같아: Predicator(frequency=73, lemma={('나같', '아')})
# 데려가서: Predicator(frequency=73, lemma={('데리', '어가서'), ('데려가', '서')})
# 괜찮소: Predicator(frequency=73, lemma={('괜찮', '소')})
# 통했네: Predicator(frequency=73, lemma={('통하', '았네')})
# 배웠는데: Predicator(frequency=73, lemma={('배', '웠는데'), ('배우', '었는데')})
# 기다리는동안: Predicator(frequency=73, lemma={('기다리', '는동안')})
# 누구요: Predicator(frequency=73, lemma={('누', '구요')})
# 똑같잖아: Predicator(frequency=73, lemma={('똑같', '잖아')})
# 이쁘군: Predicator(frequency=73, lemma={('이쁘', '군')})
# 늦지말고: Predicator(frequency=73, lemma={('늦', '지말고')})
# 있다해서: Predicator(frequency=73, lemma={('있', '다해서'), ('이', 'ㅆ다해서')})
# ------------------------------------------------------------

# %%
from soynlp.lemmatizer import _lemma_candidate
l = '먹'
for r, count in chat_predicator_extractor.lrgraph.get_r(l, topk=-1):    
    word = l + r
    word_is_extracted = word in chat_predicators

    is_stem = lambda x: x in chat_predicator_extractor._stems
    is_eomi = lambda x: x in chat_predicator_extractor._eomis
    lemmas = _lemma_candidate(l, r)
    lemmas = {(stem, eomi) for stem, eomi in lemmas
              if is_stem(stem) and is_eomi(eomi)}
    lemmas_strf = '' if not lemmas else '[%s]' % ', '.join('%s+%s'%lr for lr in lemmas)

    print('{} - {} ({}) / {} / {}extracted'.format(
        l, r, count, lemmas_strf, ' ' if word_is_extracted else 'not '))
# Out:
# 먹 - 어 (13159) / [먹+어] /  extracted
# 먹 - 었어 (10510) / [먹+었어] /  extracted
# 먹 - 구 (9331) / [먹+구] /  extracted
# 먹 - 으면 (5906) / [먹+으면] /  extracted
# 먹 - 어요 (5638) / [먹+어요] /  extracted
# 먹 - 었어요 (4201) / [먹+었어요] /  extracted
# 먹 - 어야지 (3885) / [먹+어야지] /  extracted
# 먹 - 어서 (3845) / [먹+어서] /  extracted
# 먹 - 자 (3133) / [먹+자] /  extracted
# 먹 - 엉 (2541) / [먹+엉] /  extracted
# 먹 - 을 (2467) / [먹+을] /  extracted
# 먹 - 어용 (2463) / [먹+어용] /  extracted
# 먹 - 지 (2322) / [먹+지] /  extracted
# 먹 - 어도 (2227) / [먹+어도] /  extracted
# 먹 - 었는데 (1946) / [먹+었는데] /  extracted
# 먹 - 을까 (1935) / [먹+을까] /  extracted
# 먹 - 엇어 (1825) / [먹+엇어] /  extracted
# 먹 - 었엉 (1513) / [먹+었엉] /  extracted
# 먹 - 는데 (1502) / [먹+는데] /  extracted
# 먹 - 는 (1495) / [먹+는] /  extracted
# 먹 - 으면서 (1368) / [먹+으면서] /  extracted
# 먹 - 는거 (1356) / [먹+는거] /  extracted
# 먹 - 을게 (1342) / [먹+을게] /  extracted
# 먹 - 었지 (1215) / [먹+었지] /  extracted
# 먹 - 어야징 (1208) / [먹+어야징] /  extracted
# 먹 - 어야 (1050) / [먹+어야] /  extracted
# 먹 - 게 (1044) / [먹+게] /  extracted
# 먹 - 는게 (992) / [먹+는게] /  extracted
# 먹 - 으려고 (983) / [먹+으려고] /  extracted
# 먹 - 는다 (954) / [먹+는다] /  extracted
# 먹 - 었옹 (913) / [먹+었옹] /  extracted
# 먹 - 기 (841) / [먹+기] /  extracted
# 먹 - 은 (838) / [먹+은] /  extracted
# 먹 - 으니까 (806) / [먹+으니까] /  extracted
# 먹 - 네 (737) / [먹+네] /  extracted
# 먹 - 었다 (707) / [먹+었다] /  extracted
# 먹 - 어여 (694) / [먹+어여] /  extracted
# 먹 - 으라고 (689) / [먹+으라고] /  extracted
# 먹 - 어써 (663) / [먹+어써] /  extracted
# 먹 - 었네 (660) / [먹+었네] /  extracted
# 먹 - 어라 (655) / [먹+어라] /  extracted
# 먹 - 었어용 (636) / [먹+었어용] /  extracted
# 먹 - 으려구 (630) / [먹+으려구] /  extracted
# 먹 - 오 (614) / [먹+오] /  extracted
# 먹 - 는거야 (600) / [먹+는거야] /  extracted
# 먹 - 장 (560) /  / not extracted
# 먹 - 는다고 (510) / [먹+는다고] /  extracted
# 먹 - 엇는데 (500) / [먹+엇는데] /  extracted
# 먹 - 어야겠다 (500) / [먹+어야겠다] /  extracted
# 먹 - 었나 (499) / [먹+었나] /  extracted
# 먹 - 구왕 (492) / [먹+구왕] /  extracted
# 먹 - 는건 (476) / [먹+는건] /  extracted
# 먹 - 어야해 (467) / [먹+어야해] /  extracted
# 먹 - 옹 (446) / [먹+옹] /  extracted
# 먹 - 은게 (422) / [먹+은게] /  extracted
# 먹 - 었더니 (421) / [먹+었더니] /  extracted
# 먹 - 었당 (415) / [먹+었당] /  extracted
# 먹 - 는당 (405) / [먹+는당] /  extracted
# 먹 - 을지 (381) / [먹+을지] /  extracted
# 먹 - 지말고 (338) / [먹+지말고] /  extracted
# 먹 - 엇어요 (334) / [먹+엇어요] /  extracted
# 먹 - 어떠 (330) / [먹+어떠] /  extracted
# 먹 - 엇지 (312) / [먹+엇지] /  extracted
# 먹 - 을라구 (307) / [먹+을라구] /  extracted
# 먹 - 으로 (294) /  / not extracted
# 먹 - 었으면 (287) / [먹+었으면] /  extracted
# 먹 - 었징 (286) / [먹+었징] /  extracted
# 먹 - 지도 (284) / [먹+지도] /  extracted
# 먹 - 었어여 (283) / [먹+었어여] /  extracted
# 먹 - 나 (280) / [먹+나] /  extracted
# 먹 - 어봐 (273) / [먹+어봐] /  extracted
# 먹 - 었다고 (271) / [먹+었다고] /  extracted
# 먹 - 구있어 (269) / [먹+구있어] /  extracted
# 먹 - 을게요 (266) / [먹+을게요] /  extracted
# 먹 - 으까 (264) / [먹+으까] /  extracted
# 먹 - 었구 (263) / [먹+었구] /  extracted
# 먹 - 으려구요 (261) / [먹+으려구요] /  extracted
# 먹 - 지말구 (261) / [먹+지말구] /  extracted
# 먹 - 을랭 (261) / [먹+을랭] /  extracted
# 먹 - 겠네 (250) / [먹+겠네] /  extracted
# 먹 - 징 (241) / [먹+징] /  extracted
# 먹 - 궁 (237) /  / not extracted
# 먹 - 쟝 (236) / [먹+쟝] /  extracted
# 먹 - 구싶다 (234) / [먹+구싶다] /  extracted
# 먹 - 을께 (233) / [먹+을께] /  extracted
# 먹 - 어두 (231) / [먹+어두] /  extracted
# 먹 - 냐 (224) / [먹+냐] /  extracted
# 먹 - 어야죠 (221) / [먹+어야죠] /  extracted
# 먹 - 어또 (220) / [먹+어또] /  extracted
# 먹 - 으니 (213) / [먹+으니] /  extracted
# 먹 - 었죠 (210) / [먹+었죠] /  extracted
# 먹 - 으니깐 (202) / [먹+으니깐] /  extracted
# 먹 - 었넹 (195) / [먹+었넹] /  extracted
# 먹 - 어봤어 (194) / [먹+어봤어] /  extracted
# 먹 - 느라 (192) / [먹+느라] /  extracted
# 먹 - 었던 (189) / [먹+었던] /  extracted
# 먹 - 을려구 (187) / [먹+을려구] /  extracted
# 먹 - 어야겟다 (185) / [먹+어야겟다] /  extracted
# 먹 - 넹 (185) / [먹+넹] /  extracted
# 먹 - 었나요 (181) / [먹+었나요] /  extracted
# 먹 - 으려궁 (180) / [먹+으려궁] /  extracted
# 먹 - 구싶당 (178) / [먹+구싶당] /  extracted
# 먹 - 으려공 (176) / [먹+으려공] /  extracted
# 먹 - 엇오 (175) / [먹+엇오] /  extracted
# 먹 - 으라구 (174) / [먹+으라구] /  extracted
# 먹 - 겠지 (171) / [먹+겠지] /  extracted
# 먹 - 겠다 (170) / [먹+겠다] /  extracted
# 먹 - 었으니까 (169) / [먹+었으니까] /  extracted
# 먹 - 어야돼 (166) / [먹+어야돼] /  extracted
# 먹 - 었 (164) / [먹+었] /  extracted
# 먹 - 을까요 (163) / [먹+을까요] /  extracted
# 먹 - 었으니 (162) / [먹+었으니] /  extracted
# 먹 - 어영 (162) / [먹+어영] /  extracted
# 먹 - 으렴 (159) / [먹+으렴] /  extracted
# 먹 - 거나 (159) / [먹+거나] /  extracted
# 먹 - 어줘 (158) / [먹+어줘] /  extracted
# 먹 - 어랑 (156) / [먹+어랑] /  extracted
# 먹 - 었는뎅 (153) / [먹+었는뎅] /  extracted
# 먹 - 엇당 (152) / [먹+엇당] /  extracted
# 먹 - 어쯍 (152) / [먹+어쯍] /  extracted
# 먹 - 엇다 (150) / [먹+엇다] /  extracted
# 먹 - 어봤는데 (149) / [먹+어봤는데] /  extracted
# 먹 - 어야겠어 (149) / [먹+어야겠어] /  extracted
# 먹 - 었쪄 (146) / [먹+었쪄] /  extracted
# 먹 - 었냐 (145) / [먹+었냐] /  extracted
# 먹 - 었지요 (144) / [먹+었지요] /  extracted
# 먹 - 어야겠당 (143) / [먹+어야겠당] /  extracted
# 먹 - 는구나 (142) / [먹+는구나] /  extracted
# 먹 - 으려면 (141) / [먹+으려면] /  extracted
# 먹 - 어야대 (141) / [먹+어야대] /  extracted
# 먹 - 어랏 (140) / [먹+어랏] /  extracted
# 먹 - 을겡 (138) / [먹+을겡] /  extracted
# 먹 - 공 (135) /  / not extracted
# 먹 - 던 (134) / [먹+던] /  extracted
# 먹 - 은지 (132) / [먹+은지] /  extracted
# 먹 - 엇서 (132) / [먹+엇서] /  extracted
# 먹 - 자나 (132) / [먹+자나] /  extracted
# 먹 - 엇나 (131) / [먹+엇나] /  extracted
# 먹 - 기는 (130) / [먹+기는] /  extracted
# 먹 - 어쪙 (128) / [먹+어쪙] /  extracted
# 먹 - 지뭐 (126) / [먹+지뭐] /  extracted
# 먹 - 어줘서 (125) / [먹+어줘서] /  extracted
# 먹 - 는뎅 (125) / [먹+는뎅] /  extracted
# 먹 - 어썽 (125) / [먹+어썽] /  extracted
# 먹 - 진 (124) / [먹+진] /  extracted
# 먹 - 으려구용 (124) / [먹+으려구용] /  extracted
# 먹 - 니 (121) / [먹+니] /  extracted
# 먹 - 어야겠네 (121) / [먹+어야겠네] /  extracted
# 먹 - 어야지요 (119) / [먹+어야지요] /  extracted
# 먹 - 여 (119) / [먹+여] /  extracted
# 먹 - 어야하나 (118) / [먹+어야하나] /  extracted
# 먹 - 엇더니 (117) / [먹+엇더니] /  extracted
# 먹 - 엇옹 (117) / [먹+엇옹] /  extracted
# 먹 - 은건 (115) / [먹+은건] /  extracted
# 먹 - 는다구 (115) / [먹+는다구] /  extracted
# 먹 - 지는 (113) / [먹+지는] /  extracted
# 먹 - 을땐 (112) / [먹+을땐] /  extracted
# 먹 - 었거든 (112) / [먹+었거든] /  extracted
# 먹 - 는건데 (111) / [먹+는건데] /  extracted
# 먹 - 구이써 (111) / [먹+구이써] /  extracted
# 먹 - 구싶어 (110) / [먹+구싶어] /  extracted
# 먹 - 었져 (109) / [먹+었져] /  extracted
# 먹 - 죠 (108) / [먹+죠] /  extracted
# 먹 - 어유 (108) / [먹+어유] /  extracted
# 먹 - 었지롱 (108) / [먹+었지롱] /  extracted
# 먹 - 던지 (108) / [먹+던지] /  extracted
# 먹 - 어야딩 (106) / [먹+어야딩] /  extracted
# 먹 - 엇어용 (106) / [먹+엇어용] /  extracted
# 먹 - 나요 (105) / [먹+나요] /  extracted
# 먹 - 던가 (105) / [먹+던가] /  extracted
# 먹 - 었쪙 (104) / [먹+었쪙] /  extracted
# 먹 - 어야되 (104) / [먹+어야되] /  extracted
# 먹 - 는지 (103) / [먹+는지] /  extracted
# 먹 - 을건 (102) / [먹+을건] /  extracted
# 먹 - 겡 (102) / [먹+겡] /  extracted
# 먹 - 자마자 (102) / [먹+자마자] /  extracted
# 먹 - 을깡 (101) / [먹+을깡] /  extracted
# 먹 - 었는지 (100) / [먹+었는지] /  extracted
# 먹 - 어욤 (100) / [먹+어욤] /  extracted
# 먹 - 구요 (99) / [먹+구요] /  extracted
# 먹 - 을라궁 (99) / [먹+을라궁] /  extracted
# 먹 - 었낭 (99) / [먹+었낭] /  extracted
# 먹 - 구있옹 (98) / [먹+구있옹] /  extracted
# 먹 - 었네요 (98) / [먹+었네요] /  extracted
# 먹 - 네요 (98) / [먹+네요] /  extracted
# 먹 - 어써여 (97) / [먹+어써여] /  extracted
# 먹 - 어야해요 (96) / [먹+어야해요] /  extracted
# 먹 - 어쏘 (94) / [먹+어쏘] /  extracted
# 먹 - 구있엉 (92) / [먹+구있엉] /  extracted
# 먹 - 은듯 (90) / [먹+은듯] /  extracted
# 먹 - 구잇어 (89) / [먹+구잇어] /  extracted
# 먹 - 겠넹 (88) / [먹+겠넹] /  extracted
# 먹 - 겠어 (88) / [먹+겠어] /  extracted
# 먹 - 구올게 (88) / [먹+구올게] /  extracted
# 먹 - 기가 (88) / [먹+기가] /  extracted
# 먹 - 어봄 (88) / [먹+어봄] /  extracted
# 먹 - 어써요 (87) / [먹+어써요] /  extracted
# 먹 - 을게용 (87) / [먹+을게용] /  extracted
# 먹 - 여서 (85) / [먹+여서] /  extracted
# 먹 - 었나봐 (85) / [먹+었나봐] /  extracted
# 먹 - 었지용 (84) / [먹+었지용] /  extracted
# 먹 - 어어 (83) / [먹+어어] /  extracted
# 먹 - 엇니 (83) / [먹+엇니] /  extracted
# 먹 - 으라 (82) / [먹+으라] /  extracted
# 먹 - 었으 (80) / [먹+었으] /  extracted
# 먹 - 으려고요 (80) /  / not extracted
# 먹 - 구올게용 (80) / [먹+구올게용] /  extracted
# 먹 - 어먹어 (80) / [먹+어먹어] /  extracted
# 먹 - 어야게따 (80) / [먹+어야게따] /  extracted
# 먹 - 으며 (80) / [먹+으며] /  extracted
# 먹 - 을께요 (76) / [먹+을께요] /  extracted
# 먹 - 었습니다 (76) / [먹+었습니다] /  extracted
# 먹 - 어본 (75) / [먹+어본] /  extracted
# 먹 - 엇징 (73) / [먹+엇징] /  extracted
# 먹 - 여야지 (73) / [먹+여야지] /  extracted
# 먹 - 었대 (73) / [먹+었대] /  extracted
# 먹 - 지요 (72) / [먹+지요] /  extracted
# 먹 - 었더 (72) / [먹+었더] /  extracted
# 먹 - 어야죵 (71) / [먹+어야죵] /  extracted
# 먹 - 어욥 (71) /  / not extracted
# 먹 - 자해서 (70) / [먹+자해서] /  extracted
# 먹 - 으려나 (69) / [먹+으려나] /  extracted
# 먹 - 는다며 (69) / [먹+는다며] /  extracted
# 먹 - 겟다 (68) / [먹+겟다] /  extracted
# 먹 - 어쮸웅 (68) / [먹+어쮸웅] /  extracted
# 먹 - 든 (68) / [먹+든] /  extracted
# 먹 - 엇 (68) / [먹+엇] /  extracted
# 먹 - 구가 (67) / [먹+구가] /  extracted
# 먹 - 엇더 (67) / [먹+엇더] /  extracted
# 먹 - 어쩌 (67) / [먹+어쩌] /  extracted
# 먹 - 어봐요 (67) / [먹+어봐요] /  extracted
# 먹 - 자아 (67) / [먹+자아] /  extracted
# 먹 - 었닝 (67) / [먹+었닝] /  extracted
# 먹 - 거라 (67) / [먹+거라] /  extracted
# 먹 - 을텐데 (66) / [먹+을텐데] /  extracted
# 먹 - 었는데도 (66) / [먹+었는데도] /  extracted
# 먹 - 기엔 (66) / [먹+기엔] /  extracted
# 먹 - 는거는 (66) / [먹+는거는] /  extracted
# 먹 - 었지만 (65) / [먹+었지만] /  extracted
# 먹 - 구있어요 (65) / [먹+구있어요] /  extracted
# 먹 - 자용 (65) / [먹+자용] /  extracted
# 먹 - 기위해 (65) / [먹+기위해] /  extracted
# 먹 - 으 (64) /  / not extracted
# 먹 - 을려궁 (63) /  / not extracted
# 먹 - 어염 (63) / [먹+어염] /  extracted
# 먹 - 이면 (63) /  /  extracted
# 먹 - 었졍 (63) / [먹+었졍] /  extracted
# 먹 - 는줄 (63) / [먹+는줄] /  extracted
# 먹 - 었다구 (63) / [먹+었다구] /  extracted
# 먹 - 었나용 (62) / [먹+었나용] /  extracted
# 먹 - 겟지 (62) / [먹+겟지] /  extracted
# 먹 - 지말라고 (60) / [먹+지말라고] /  extracted
# 먹 - 눈당 (60) /  / not extracted
# 먹 - 냐고 (60) / [먹+냐고] /  extracted
# 먹 - 은건데 (60) / [먹+은건데] /  extracted
# 먹 - 겟네 (60) / [먹+겟네] /  extracted
# 먹 - 어성 (59) / [먹+어성] /  extracted
# 먹 - 는거면 (59) / [먹+는거면] /  extracted
# 먹 - 는닷 (59) / [먹+는닷] /  extracted
# 먹 - 을려구요 (59) /  / not extracted
# 먹 - 을까말까 (59) /  / not extracted
# 먹 - 구우 (58) / [먹+구우] /  extracted
# 먹 - 었길래 (58) / [먹+었길래] /  extracted
# 먹 - 구이쪄 (58) / [먹+구이쪄] /  extracted
# 먹 - 자는데 (58) / [먹+자는데] /  extracted
# 먹 - 엌 (58) / [먹+엌] /  extracted
# 먹 - 어융 (58) /  / not extracted
# 먹 - 어야겠어요 (57) / [먹+어야겠어요] /  extracted
# 먹 - 는다용 (57) / [먹+는다용] /  extracted
# 먹 - 거든 (57) / [먹+거든] /  extracted
# 먹 - 을게없어 (57) /  / not extracted
# 먹 - 었다용 (56) / [먹+었다용] /  extracted
# 먹 - 으라용 (56) /  / not extracted
# 먹 - 었구만 (55) / [먹+었구만] /  extracted
# 먹 - 엇닝 (55) / [먹+엇닝] /  extracted
# 먹 - 지만 (55) / [먹+지만] /  extracted
# 먹 - 구올겡 (55) / [먹+구올겡] /  extracted
# 먹 - 습니다 (55) / [먹+습니다] /  extracted
# 먹 - 게요 (55) / [먹+게요] /  extracted
# 먹 - 어야겟당 (55) / [먹+어야겟당] /  extracted
# 먹 - 엇으니 (54) / [먹+엇으니] /  extracted
# 먹 - 낭 (54) /  / not extracted
# 먹 - 었도 (54) / [먹+었도] /  extracted
# 먹 - 는거얌 (54) / [먹+는거얌] /  extracted
# 먹 - 엇구 (54) / [먹+엇구] /  extracted
# 먹 - 엇넹 (54) / [먹+엇넹] /  extracted
# 먹 - 엇음 (54) / [먹+엇음] /  extracted
# 먹 - 어야겟어 (54) / [먹+어야겟어] /  extracted
# 먹 - 는댕 (53) / [먹+는댕] /  extracted
# 먹 - 엇고 (53) / [먹+엇고] /  extracted
# 먹 - 었겠네 (53) / [먹+었겠네] /  extracted
# 먹 - 지말자 (53) / [먹+지말자] /  extracted
# 먹 - 던데 (52) / [먹+던데] /  extracted
# 먹 - 으려고용 (52) /  / not extracted
# 먹 - 엇져 (51) / [먹+엇져] /  extracted
# 먹 - 는듯 (51) / [먹+는듯] /  extracted
# 먹 - 어야쥐 (51) / [먹+어야쥐] /  extracted
# 먹 - 었다능 (51) / [먹+었다능] /  extracted
# 먹 - 더니 (51) / [먹+더니] /  extracted
# 먹 - 는거랑 (51) / [먹+는거랑] /  extracted
# 먹 - 엇으면 (51) / [먹+엇으면] /  extracted
# 먹 - 었냥 (51) / [먹+었냥] /  extracted
# 먹 - 으라니까 (50) / [먹+으라니까] /  extracted
# 먹 - 어요옹 (49) / [먹+어요옹] /  extracted
# 먹 - 는다는 (49) / [먹+는다는] /  extracted
# 먹 - 으라능 (49) /  / not extracted
# 먹 - 엇서용 (49) / [먹+엇서용] /  extracted
# 먹 - 으려 (49) / [먹+으려] /  extracted
# 먹 - 엇다고 (49) / [먹+엇다고] /  extracted
# 먹 - 더라 (48) / [먹+더라] /  extracted
# 먹 - 자요 (48) / [먹+자요] /  extracted
# 먹 - 오용 (48) / [먹+오용] /  extracted
# 먹 - 겠당 (48) / [먹+겠당] /  extracted
# 먹 - 어가면서 (48) / [먹+어가면서] /  extracted
# 먹 - 어뚜 (47) / [먹+어뚜] /  extracted
# 먹 - 거 (47) /  / not extracted
# 먹 - 었으니깐 (47) / [먹+었으니깐] /  extracted
# 먹 - 었눈데 (47) / [먹+었눈데] /  extracted
# 먹 - 었었는데 (47) / [먹+었었는데] /  extracted
# 먹 - 어야겟네 (46) / [먹+어야겟네] /  extracted
# 먹 - 는듕 (46) / [먹+는듕] /  extracted
# 먹 - 을라면 (46) / [먹+을라면] /  extracted
# 먹 - 어보면 (46) / [먹+어보면] /  extracted
# 먹 - 은겨 (46) / [먹+은겨] /  extracted
# 먹 - 을려공 (46) /  / not extracted
# 먹 - 어여지 (46) / [먹+어여지] /  extracted
# 먹 - 었또 (45) / [먹+었또] /  extracted
# 먹 - 이구 (45) /  /  extracted
# 먹 - 어땅 (45) / [먹+어땅] /  extracted
# 먹 - 는구만 (44) / [먹+는구만] /  extracted
# 먹 - 었다니 (44) / [먹+었다니] /  extracted
# 먹 - 을게여 (44) / [먹+을게여] /  extracted
# 먹 - 어봥 (44) / [먹+어봥] /  extracted
# 먹 - 든지 (44) / [먹+든지] /  extracted
# 먹 - 을순 (44) / [먹+을순] /  extracted
# 먹 - 어봐서 (44) / [먹+어봐서] /  extracted
# 먹 - 지망 (43) / [먹+지망] /  extracted
# 먹 - 을라구요 (43) /  / not extracted
# 먹 - 어오 (43) / [먹+어오] /  extracted
# 먹 - 을지도 (43) / [먹+을지도] /  extracted
# 먹 - 었겠지 (43) / [먹+었겠지] /  extracted
# 먹 - 구있당 (43) / [먹+구있당] /  extracted
# 먹 - 겠습니다 (43) / [먹+겠습니다] /  extracted
# 먹 - 어줄게 (43) / [먹+어줄게] /  extracted
# 먹 - 길래 (42) / [먹+길래] /  extracted
# 먹 - 여줘 (42) / [먹+여줘] /  extracted
# 먹 - 었냐고 (42) / [먹+었냐고] /  extracted
# 먹 - 움 (42) /  / not extracted
# 먹 - 기싫어 (42) / [먹+기싫어] /  extracted
# 먹 - 을고야 (42) / [먹+을고야] /  extracted
# 먹 - 었덩 (42) / [먹+었덩] /  extracted
# 먹 - 기시러 (42) / [먹+기시러] /  extracted
# 먹 - 어야하는뎅 (41) / [먹+어야하는뎅] /  extracted
# 먹 - 어봐야징 (41) / [먹+어봐야징] /  extracted
# 먹 - 이 (41) / [먹+이] /  extracted
# 먹 - 어야행 (41) / [먹+어야행] /  extracted
# 먹 - 든가 (41) / [먹+든가] /  extracted
# 먹 - 엇는뎅 (41) / [먹+엇는뎅] /  extracted
# 먹 - 제 (41) / [먹+제] /  extracted
# 먹 - 구있오 (41) / [먹+구있오] /  extracted
# 먹 - 을라공 (41) /  / not extracted
# 먹 - 우 (41) /  / not extracted
# 먹 - 으려다가 (40) / [먹+으려다가] /  extracted
# 먹 - 을껭 (40) / [먹+을껭] /  extracted
# 먹 - 어주고 (40) / [먹+어주고] /  extracted
# 먹 - 꿍 (40) /  / not extracted
# 먹 - 었구낭 (40) / [먹+었구낭] /  extracted
# 먹 - 겠네요 (39) / [먹+겠네요] /  extracted
# 먹 - 을지는 (39) / [먹+을지는] /  extracted
# 먹 - 어버렸어 (39) / [먹+어버렸어] /  extracted
# 먹 - 었습니당 (39) / [먹+었습니당] /  extracted
# 먹 - 어바 (39) / [먹+어바] /  extracted
# 먹 - 어떵 (39) / [먹+어떵] /  extracted
# 먹 - 어야할텐데 (39) / [먹+어야할텐데] /  extracted
# 먹 - 어야할듯 (39) / [먹+어야할듯] /  extracted
# 먹 - 는군 (39) / [먹+는군] /  extracted
# 먹 - 지모 (39) / [먹+지모] /  extracted
# 먹 - 지말까 (39) / [먹+지말까] /  extracted
# 먹 - 어똥 (38) /  / not extracted
# 먹 - 었슈 (38) /  / not extracted
# 먹 - 어가지고 (38) / [먹+어가지고] /  extracted
# 먹 - 는거양 (38) / [먹+는거양] /  extracted
# 먹 - 었나보네 (38) / [먹+었나보네] /  extracted
# 먹 - 는겨 (38) / [먹+는겨] /  extracted
# 먹 - 어봣는데 (37) / [먹+어봣는데] /  extracted
# 먹 - 자먹자 (37) /  / not extracted
# 먹 - 는거만 (37) / [먹+는거만] /  extracted
# 먹 - 어줘야지 (37) / [먹+어줘야지] /  extracted
# 먹 - 을가 (37) / [먹+을가] /  extracted
# 먹 - 엇죠 (37) / [먹+엇죠] /  extracted
# 먹 - 을까봐 (37) / [먹+을까봐] /  extracted
# 먹 - 어야댕 (37) / [먹+어야댕] /  extracted
# 먹 - 지머 (37) / [먹+지머] /  extracted
# 먹 - 어쩡 (37) / [먹+어쩡] /  extracted
# 먹 - 었따 (37) / [먹+었따] /  extracted
# 먹 - 을라 (37) / [먹+을라] /  extracted
# 먹 - 으려구여 (37) /  / not extracted
# 먹 - 어봤어요 (36) / [먹+어봤어요] /  extracted
# 먹 - 으시 (36) / [먹+으시] /  extracted
# 먹 - 어야해서 (36) / [먹+어야해서] /  extracted
# 먹 - 구있어용 (36) / [먹+구있어용] /  extracted
# 먹 - 을겨 (36) / [먹+을겨] /  extracted
# 먹 - 을까나 (36) / [먹+을까나] /  extracted
# 먹 - 었겠다 (36) / [먹+었겠다] /  extracted
# 먹 - 었는가 (35) / [먹+었는가] /  extracted
# 먹 - 엇으 (35) / [먹+엇으] /  extracted
# 먹 - 으면돼 (35) /  / not extracted
# 먹 - 구용 (35) / [먹+구용] /  extracted
# 먹 - 었구요 (35) / [먹+었구요] /  extracted
# 먹 - 어야함 (35) / [먹+어야함] /  extracted
# 먹 - 을려면 (35) / [먹+을려면] /  extracted
# 먹 - 는거니까 (35) / [먹+는거니까] /  extracted
# 먹 - 은줄 (35) / [먹+은줄] /  extracted
# 먹 - 나봐 (35) / [먹+나봐] /  extracted
# 먹 - 지를 (35) / [먹+지를] /  extracted
# 먹 - 었어영 (35) / [먹+었어영] /  extracted
# 먹 - 었다며 (34) / [먹+었다며] /  extracted
# 먹 - 엇지요 (34) / [먹+엇지요] /  extracted
# 먹 - 어주면 (34) / [먹+어주면] /  extracted
# 먹 - 을라구용 (34) /  / not extracted
# 먹 - 는고야 (34) / [먹+는고야] /  extracted
# 먹 - 겠다고 (34) / [먹+겠다고] /  extracted
# 먹 - 엇낭 (34) / [먹+엇낭] /  extracted
# 먹 - 어야되나 (33) / [먹+어야되나] /  extracted
# 먹 - 어봣어 (33) / [먹+어봣어] /  extracted
# 먹 - 었남 (33) / [먹+었남] /  extracted
# 먹 - 어요오 (33) / [먹+어요오] /  extracted
# 먹 - 어놓고 (33) / [먹+어놓고] /  extracted
# 먹 - 었을때 (33) / [먹+었을때] /  extracted
# 먹 - 어야하니까 (33) / [먹+어야하니까] /  extracted
# 먹 - 을게없어서 (33) /  / not extracted
# 먹 - 나용 (33) / [먹+나용] /  extracted
# 먹 - 엇냐 (33) / [먹+엇냐] /  extracted
# 먹 - 었죵 (33) / [먹+었죵] /  extracted
# 먹 - 엇눈데 (33) / [먹+엇눈데] /  extracted
# 먹 - 구싶따 (32) /  / not extracted
# 먹 - 자는 (32) / [먹+자는] /  extracted
# 먹 - 길 (32) / [먹+길] /  extracted
# 먹 - 겠군 (32) / [먹+겠군] /  extracted
# 먹 - 여줘서 (32) / [먹+여줘서] /  extracted
# 먹 - 게용 (32) / [먹+게용] /  extracted
# 먹 - 구싶어서 (32) / [먹+구싶어서] /  extracted
# 먹 - 어야져 (32) / [먹+어야져] /  extracted
# 먹 - 어봐야 (32) / [먹+어봐야] /  extracted
# 먹 - 었다가 (31) / [먹+었다가] /  extracted
# 먹 - 었었어 (31) / [먹+었었어] /  extracted
# 먹 - 을께용 (31) / [먹+을께용] /  extracted
# 먹 - 었다니까 (31) / [먹+었다니까] /  extracted
# 먹 - 으랭 (31) / [먹+으랭] /  extracted
# 먹 - 구싶은데 (31) / [먹+구싶은데] /  extracted
# 먹 - 을라했는데 (31) / [먹+을라했는데] /  extracted
# 먹 - 었쏘 (31) / [먹+었쏘] /  extracted
# 먹 - 냥 (31) /  / not extracted
# 먹 - 어떠요 (31) / [먹+어떠요] /  extracted
# 먹 - 지용 (31) / [먹+지용] /  extracted
# 먹 - 엇졍 (30) / [먹+엇졍] /  extracted
# 먹 - 는거징 (30) / [먹+는거징] /  extracted
# 먹 - 어쓰 (30) / [먹+어쓰] /  extracted
# 먹 - 어야겠지 (30) / [먹+어야겠지] /  extracted
# 먹 - 었으려나 (30) / [먹+었으려나] /  extracted
# 먹 - 을까아 (30) / [먹+을까아] /  extracted
# 먹 - 엇슈 (30) /  / not extracted
# 먹 - 어야짓 (30) / [먹+어야짓] /  extracted
# 먹 - 는다아 (29) / [먹+는다아] /  extracted
# 먹 - 는거같아 (29) / [먹+는거같아] /  extracted
# 먹 - 으려했는데 (29) / [먹+으려했는데] /  extracted
# 먹 - 었어욤 (29) / [먹+었어욤] /  extracted
# 먹 - 는거고 (29) / [먹+는거고] /  extracted
# 먹 - 으세요 (29) / [먹+으세요] /  extracted
# 먹 - 어야겠넹 (29) / [먹+어야겠넹] /  extracted
# 먹 - 어야대는데 (29) / [먹+어야대는데] /  extracted
# 먹 - 으라는 (29) / [먹+으라는] /  extracted
# 먹 - 을까용 (29) / [먹+을까용] /  extracted
# 먹 - 엇던 (29) / [먹+엇던] /  extracted
# 먹 - 었나앙 (29) / [먹+었나앙] /  extracted
# 먹 - 어잉 (29) / [먹+어잉] /  extracted
# 먹 - 어가지구 (28) / [먹+어가지구] /  extracted
# 먹 - 는다요 (28) / [먹+는다요] /  extracted
# 먹 - 오요 (28) / [먹+오요] /  extracted
# 먹 - 구잇엉 (28) / [먹+구잇엉] /  extracted
# 먹 - 어보니 (28) / [먹+어보니] /  extracted
# 먹 - 언 (28) /  / not extracted
# 먹 - 눈데 (27) / [먹+눈데] /  extracted
# 먹 - 기에는 (27) / [먹+기에는] /  extracted
# 먹 - 었누 (27) / [먹+었누] /  extracted
# 먹 - 구파 (27) / [먹+구파] /  extracted
# 먹 - 이를 (27) /  / not extracted
# 먹 - 지롱 (27) / [먹+지롱] /  extracted
# 먹 - 어죠 (27) / [먹+어죠] /  extracted
# 먹 - 었다아 (27) / [먹+었다아] /  extracted
# 먹 - 어가 (27) / [먹+어가] /  extracted
# 먹 - 었나봐요 (27) / [먹+었나봐요] /  extracted
# 먹 - 었을 (27) / [먹+었을] /  extracted
# 먹 - 어야지용 (27) /  / not extracted
# 먹 - 는디 (27) / [먹+는디] /  extracted
# 먹 - 는데도 (27) / [먹+는데도] /  extracted
# 먹 - 겟어 (26) / [먹+겟어] /  extracted
# 먹 - 자며 (26) / [먹+자며] /  extracted
# 먹 - 었다는 (26) / [먹+었다는] /  extracted
# 먹 - 엇덩 (26) / [먹+엇덩] /  extracted
# 먹 - 자하면 (26) / [먹+자하면] /  extracted
# 먹 - 을랬는데 (26) / [먹+을랬는데] /  extracted
# 먹 - 었지이 (26) / [먹+었지이] /  extracted
# 먹 - 으루 (26) /  / not extracted
# 먹 - 는구낭 (26) / [먹+는구낭] /  extracted
# 먹 - 구싶어요 (26) / [먹+구싶어요] /  extracted
# 먹 - 는다니 (26) / [먹+는다니] /  extracted
# 먹 - 더라도 (26) / [먹+더라도] /  extracted
# 먹 - 어쮸 (26) / [먹+어쮸] /  extracted
# 먹 - 었으면서 (26) / [먹+었으면서] /  extracted
# 먹 - 으라는데 (26) / [먹+으라는데] /  extracted
# 먹 - 였어 (26) / [먹+였어] /  extracted
# 먹 - 자낭 (25) / [먹+자낭] /  extracted
# 먹 - 을건가요 (25) /  / not extracted
# 먹 - 여야겠다 (25) /  /  extracted
# 먹 - 자는거 (25) / [먹+자는거] /  extracted
# 먹 - 는다면 (25) / [먹+는다면] /  extracted
# 먹 - 을건뎅 (25) / [먹+을건뎅] /  extracted
# 먹 - 을껴 (25) / [먹+을껴] /  extracted
# 먹 - 지말궁 (25) / [먹+지말궁] /  extracted
# 먹 - 엇으니까 (25) / [먹+엇으니까] /  extracted
# 먹 - 었나보다 (25) / [먹+었나보다] /  extracted
# 먹 - 으라해서 (25) /  / not extracted
# 먹 - 을까여 (25) / [먹+을까여] /  extracted
# 먹 - 었군 (25) / [먹+었군] /  extracted
# 먹 - 어욧 (24) / [먹+어욧] /  extracted
# 먹 - 어써용 (24) / [먹+어써용] /  extracted
# 먹 - 어야하고 (24) / [먹+어야하고] /  extracted
# 먹 - 여야 (24) / [먹+여야] /  extracted
# 먹 - 엇냥 (24) / [먹+엇냥] /  extracted
# 먹 - 을복이 (24) /  / not extracted
# 먹 - 어야겠네요 (24) / [먹+어야겠네요] /  extracted
# 먹 - 구왔옹 (24) / [먹+구왔옹] /  extracted
# 먹 - 는거보다 (24) / [먹+는거보다] /  extracted
# 먹 - 구있낭 (24) / [먹+구있낭] /  extracted
# 먹 - 는다니까 (24) / [먹+는다니까] /  extracted
# 먹 - 나보네 (24) / [먹+나보네] /  extracted
# 먹 - 어도되 (24) / [먹+어도되] /  extracted
# 먹 - 구잇오 (24) / [먹+구잇오] /  extracted
# 먹 - 기싫어서 (24) / [먹+기싫어서] /  extracted
# 먹 - 는거도 (24) / [먹+는거도] /  extracted
# 먹 - 어두대 (24) / [먹+어두대] /  extracted
# 먹 - 으면서도 (23) / [먹+으면서도] /  extracted
# 먹 - 은데 (23) / [먹+은데] /  extracted
# 먹 - 어떠여 (23) / [먹+어떠여] /  extracted
# 먹 - 는고 (23) / [먹+는고] /  extracted
# 먹 - 었아 (23) / [먹+었아] /  extracted
# 먹 - 을램 (23) / [먹+을램] /  extracted
# 먹 - 는거로 (23) / [먹+는거로] /  extracted
# 먹 - 엇거든 (23) / [먹+엇거든] /  extracted
# 먹 - 지않을까 (23) / [먹+지않을까] /  extracted
# 먹 - 기싫다 (23) / [먹+기싫다] /  extracted
# 먹 - 는날 (23) / [먹+는날] /  extracted
# 먹 - 었을텐데 (23) / [먹+었을텐데] /  extracted
# 먹 - 엇길래 (23) / [먹+엇길래] /  extracted
# 먹 - 닝 (23) /  / not extracted
# 먹 - 었어야지 (23) / [먹+었어야지] /  extracted
# 먹 - 겟당 (22) / [먹+겟당] /  extracted
# 먹 - 구싶오 (22) / [먹+구싶오] /  extracted
# 먹 - 어야하지 (22) / [먹+어야하지] /  extracted
# 먹 - 었다요 (22) / [먹+었다요] /  extracted
# 먹 - 어야되요 (22) / [먹+어야되요] /  extracted
# 먹 - 는거아냐 (22) / [먹+는거아냐] /  extracted
# 먹 - 구이쏘 (22) / [먹+구이쏘] /  extracted
# 먹 - 으라요 (22) / [먹+으라요] /  extracted
# 먹 - 는다길래 (22) /  / not extracted
# 먹 - 을껀 (22) /  / not extracted
# 먹 - 어두되 (22) / [먹+어두되] /  extracted
# 먹 - 을테니 (22) / [먹+을테니] /  extracted
# 먹 - 엇는지 (22) / [먹+엇는지] /  extracted
# 먹 - 어야되는뎅 (22) / [먹+어야되는뎅] /  extracted
# 먹 - 으세용 (22) / [먹+으세용] /  extracted
# 먹 - 이려고 (22) /  /  extracted
# 먹 - 어둬 (21) / [먹+어둬] /  extracted
# 먹 - 자네 (21) / [먹+자네] /  extracted
# 먹 - 으라니깐 (21) /  / not extracted
# 먹 - 어야되서 (21) / [먹+어야되서] /  extracted
# 먹 - 는건지 (21) / [먹+는건지] /  extracted
# 먹 - 었나봥 (21) / [먹+었나봥] /  extracted
# 먹 - 겟넹 (21) / [먹+겟넹] /  extracted
# 먹 - 어야할지 (21) / [먹+어야할지] /  extracted
# 먹 - 으셈 (21) / [먹+으셈] /  extracted
# 먹 - 구올게요 (21) /  / not extracted
# 먹 - 었던데 (21) / [먹+었던데] /  extracted
# 먹 - 을라나 (21) / [먹+을라나] /  extracted
# 먹 - 구시픈거 (21) /  / not extracted
# 먹 - 어라아 (21) / [먹+어라아] /  extracted
# 먹 - 은만큼 (21) / [먹+은만큼] /  extracted
# 먹 - 었잖앙 (21) / [먹+었잖앙] /  extracted
# 먹 - 구해 (21) /  / not extracted
# 먹 - 는거다 (21) / [먹+는거다] /  extracted
# 먹 - 엇나봐 (21) / [먹+엇나봐] /  extracted
# 먹 - 지두 (21) / [먹+지두] /  extracted
# 먹 - 어뗘 (21) / [먹+어뗘] /  extracted
# 먹 - 을게없다 (21) /  / not extracted
# 먹 - 으려다 (21) / [먹+으려다] /  extracted
# 먹 - 이는 (21) /  /  extracted
# 먹 - 어야한다 (21) / [먹+어야한다] /  extracted
# 먹 - 구여 (20) / [먹+구여] /  extracted
# 먹 - 는거임 (20) / [먹+는거임] /  extracted
# 먹 - 는데요 (20) / [먹+는데요] /  extracted
# 먹 - 어야할 (20) / [먹+어야할] /  extracted
# 먹 - 을둡 (20) / [먹+을둡] /  extracted
# 먹 - 어서요 (20) / [먹+어서요] /  extracted
# 먹 - 어야집 (20) / [먹+어야집] /  extracted
# 먹 - 어야됭 (20) / [먹+어야됭] /  extracted
# 먹 - 었는데요 (20) / [먹+었는데요] /  extracted
# 먹 - 는다는데 (20) / [먹+는다는데] /  extracted
# 먹 - 는다더니 (20) / [먹+는다더니] /  extracted
# 먹 - 어주지 (20) / [먹+어주지] /  extracted
# 먹 - 는데용 (20) / [먹+는데용] /  extracted
# 먹 - 을려구용 (20) /  / not extracted
# 먹 - 어줭 (20) / [먹+어줭] /  extracted
# 먹 - 구싶구 (20) /  / not extracted
# 먹 - 엇다구 (20) / [먹+엇다구] /  extracted
# 먹 - 는거죠 (20) / [먹+는거죠] /  extracted
# 먹 - 엇지용 (20) / [먹+엇지용] /  extracted
# 먹 - 었거든요 (20) / [먹+었거든요] /  extracted
# 먹 - 을지말지 (20) /  / not extracted
# 먹 - 었소 (20) / [먹+었소] /  extracted
# 먹 - 었네에 (20) / [먹+었네에] /  extracted
# 먹 - 누 (20) / [먹+누] /  extracted
# 먹 - 엇어여 (19) / [먹+엇어여] /  extracted
# 먹 - 었꿍 (19) /  / not extracted
# 먹 - 구있오용 (19) / [먹+구있오용] /  extracted
# 먹 - 눈다 (19) / [먹+눈다] /  extracted
# 먹 - 으라궁 (19) /  / not extracted
# 먹 - 자했는데 (19) / [먹+자했는데] /  extracted
# 먹 - 겠다는 (19) / [먹+겠다는] /  extracted
# 먹 - 었어서 (19) / [먹+었어서] /  extracted
# 먹 - 엇잖아 (19) / [먹+엇잖아] /  extracted
# 먹 - 구왓 (19) / [먹+구왓] /  extracted
# 먹 - 을테다 (19) /  / not extracted
# 먹 - 을라햇는데 (19) /  / not extracted
# 먹 - 었졉 (19) / [먹+었졉] /  extracted
# 먹 - 았어 (19) / [먹+았어] /  extracted
# 먹 - 어야댐 (19) / [먹+어야댐] /  extracted
# 먹 - 구잇어용 (19) / [먹+구잇어용] /  extracted
# 먹 - 으깡 (19) / [먹+으깡] /  extracted
# 먹 - 지않아 (19) / [먹+지않아] /  extracted
# 먹 - 는다하면 (19) /  / not extracted
# 먹 - 었던게 (19) / [먹+었던게] /  extracted
# 먹 - 어봤엉 (19) / [먹+어봤엉] /  extracted
# 먹 - 었우 (19) /  / not extracted
# 먹 - 엇구나 (19) / [먹+엇구나] /  extracted
# 먹 - 어야하구 (19) / [먹+어야하구] /  extracted
# 먹 - 을게없네 (19) /  / not extracted
# 먹 - 어야됑 (19) / [먹+어야됑] /  extracted
# 먹 - 은날 (19) / [먹+은날] /  extracted
# 먹 - 었단 (19) / [먹+었단] /  extracted
# 먹 - 었어야 (19) / [먹+었어야] /  extracted
# 먹 - 을라규 (18) /  / not extracted
# 먹 - 엇으니깐 (18) / [먹+엇으니깐] /  extracted
# 먹 - 을라거 (18) /  / not extracted
# 먹 - 으랴구 (18) /  / not extracted
# 먹 - 어보겠습니다 (18) / [먹+어보겠습니다] /  extracted
# 먹 - 구이쩌 (18) / [먹+구이쩌] /  extracted
# 먹 - 었는대 (18) / [먹+었는대] /  extracted
# 먹 - 어야겠엉 (18) / [먹+어야겠엉] /  extracted
# 먹 - 어보라고 (18) / [먹+어보라고] /  extracted
# 먹 - 는단 (18) / [먹+는단] /  extracted
# 먹 - 어봐써 (18) / [먹+어봐써] /  extracted
# 먹 - 울래 (18) / [먹+울래] /  extracted
# 먹 - 을껀뎅 (18) / [먹+을껀뎅] /  extracted
# 먹 - 어봤나 (18) / [먹+어봤나] /  extracted
# 먹 - 었눈뎅 (17) / [먹+었눈뎅] /  extracted
# 먹 - 을레 (17) /  / not extracted
# 먹 - 었떵 (17) / [먹+었떵] /  extracted
# 먹 - 는다는게 (17) / [먹+는다는게] /  extracted
# 먹 - 을까낭 (17) / [먹+을까낭] /  extracted
# 먹 - 었냐능 (17) / [먹+었냐능] /  extracted
# 먹 - 겠죠 (17) / [먹+겠죠] /  extracted
# 먹 - 었을까 (17) / [먹+었을까] /  extracted
# 먹 - 어양 (17) / [먹+어양] /  extracted
# 먹 - 는댜 (17) / [먹+는댜] /  extracted
# 먹 - 어보니까 (17) / [먹+어보니까] /  extracted
# 먹 - 었찡 (17) /  / not extracted
# 먹 - 어야지잉 (17) /  / not extracted
# 먹 - 으고 (17) /  / not extracted
# 먹 - 었궁 (17) / [먹+었궁] /  extracted
# 먹 - 어달라고 (17) / [먹+어달라고] /  extracted
# 먹 - 었느냐 (17) / [먹+었느냐] /  extracted
# 먹 - 을려다가 (17) /  / not extracted
# 먹 - 어줘야해 (17) / [먹+어줘야해] /  extracted
# 먹 - 혔어 (17) / [먹+혔어] /  extracted
# 먹 - 구잇당 (17) / [먹+구잇당] /  extracted
# 먹 - 기싫은데 (17) / [먹+기싫은데] /  extracted
# 먹 - 어줄 (17) / [먹+어줄] /  extracted
# 먹 - 여줄겡 (17) /  /  extracted
# 먹 - 엇대 (17) / [먹+엇대] /  extracted
# 먹 - 지말지 (17) / [먹+지말지] /  extracted
# 먹 - 어보쟈 (17) /  / not extracted
# 먹 - 엇찌 (17) / [먹+엇찌] /  extracted
# 먹 - 었는뎁 (17) / [먹+었는뎁] /  extracted
# 먹 - 어그럼 (17) / [먹+어그럼] /  extracted
# 먹 - 어야하는 (17) / [먹+어야하는] /  extracted
# 먹 - 구잇어요 (17) / [먹+구잇어요] /  extracted
# 먹 - 어봐용 (17) / [먹+어봐용] /  extracted
# 먹 - 으묜 (17) / [먹+으묜] /  extracted
# 먹 - 으라해 (16) /  / not extracted
# 먹 - 쨩 (16) /  / not extracted
# 먹 - 었어요옹 (16) /  / not extracted
# 먹 - 지뭥 (16) / [먹+지뭥] /  extracted
# 먹 - 구옴 (16) / [먹+구옴] /  extracted
# 먹 - 었던곳 (16) /  / not extracted
# 먹 - 태 (16) /  / not extracted
# 먹 - 디마 (16) / [먹+디마] /  extracted
# 먹 - 는다해서 (16) /  / not extracted
# 먹 - 는뎁 (16) / [먹+는뎁] /  extracted
# 먹 - 구있다 (16) / [먹+구있다] /  extracted
# 먹 - 는가 (16) / [먹+는가] /  extracted
# 먹 - 엇쥬 (16) / [먹+엇쥬] /  extracted
# 먹 - 여주면 (16) / [먹+여주면] /  extracted
# 먹 - 겠구만 (16) / [먹+겠구만] /  extracted
# 먹 - 었더닝 (16) /  / not extracted
# 먹 - 는답 (16) /  / not extracted
# 먹 - 어쬬 (16) / [먹+어쬬] /  extracted
# 먹 - 자니까 (16) /  / not extracted
# 먹 - 어버렷어 (16) / [먹+어버렷어] /  extracted
# 먹 - 으려는데 (16) / [먹+으려는데] /  extracted
# 먹 - 어찡 (16) /  / not extracted
# 먹 - 지잉 (16) /  / not extracted
# 먹 - 겠징 (16) / [먹+겠징] /  extracted
# 먹 - 히는 (16) /  /  extracted
# 먹 - 어야쥬 (16) / [먹+어야쥬] /  extracted
# 먹 - 을라다가 (16) /  / not extracted
# 먹 - 여살릴게 (16) /  / not extracted
# 먹 - 져 (16) /  / not extracted
# 먹 - 일 (16) /  /  extracted
# 먹 - 었어도 (16) / [먹+었어도] /  extracted
# 먹 - 는건뎅 (15) / [먹+는건뎅] /  extracted
# 먹 - 을려 (15) /  / not extracted
# 먹 - 는다면서 (15) /  / not extracted
# 먹 - 네용 (15) / [먹+네용] /  extracted
# 먹 - 었나바 (15) / [먹+었나바] /  extracted
# 먹 - 어야게땅 (15) / [먹+어야게땅] /  extracted
# 먹 - 구왔당 (15) / [먹+구왔당] /  extracted
# 먹 - 는다능 (15) / [먹+는다능] /  extracted
# 먹 - 겠어요 (15) / [먹+겠어요] /  extracted
# 먹 - 남 (15) /  / not extracted
# 먹 - 어보 (15) / [먹+어보] /  extracted
# 먹 - 었기 (15) / [먹+었기] /  extracted
# 먹 - 었동 (15) / [먹+었동] /  extracted
# 먹 - 엇도 (15) / [먹+엇도] /  extracted
# 먹 - 을테야 (15) / [먹+을테야] /  extracted
# 먹 - 엇지롱 (15) / [먹+엇지롱] /  extracted
# 먹 - 어보진 (15) / [먹+어보진] /  extracted
# 먹 - 을테니까 (15) / [먹+을테니까] /  extracted
# 먹 - 었쬬 (15) / [먹+었쬬] /  extracted
# 먹 - 어야되지 (15) / [먹+어야되지] /  extracted
# 먹 - 으껭 (15) / [먹+으껭] /  extracted
# 먹 - 읍시당 (15) /  / not extracted
# 먹 - 어줘야 (15) / [먹+어줘야] /  extracted
# 먹 - 으삼 (15) / [먹+으삼] /  extracted
# 먹 - 어줄께 (15) / [먹+어줄께] /  extracted
# 먹 - 었냐구 (15) / [먹+었냐구] /  extracted
# 먹 - 는거니깐 (15) / [먹+는거니깐] /  extracted
# 먹 - 었는 (15) / [먹+었는] /  extracted
# 먹 - 으까아 (15) / [먹+으까아] /  extracted
# 먹 - 어보장 (15) / [먹+어보장] /  extracted
# 먹 - 엇죵 (15) / [먹+엇죵] /  extracted
# 먹 - 을랴고 (15) / [먹+을랴고] /  extracted
# 먹 - 어보게 (15) / [먹+어보게] /  extracted
# 먹 - 었쪄어 (15) /  / not extracted
# 먹 - 어두돼 (15) / [먹+어두돼] /  extracted
# 먹 - 구잇더 (15) / [먹+구잇더] /  extracted
# 먹 - 구올껭 (15) /  / not extracted
# 먹 - 었거등 (15) / [먹+었거등] /  extracted
# 먹 - 을랫는데 (15) /  / not extracted
# 먹 - 내 (14) /  / not extracted
# 먹 - 었는딩 (14) / [먹+었는딩] /  extracted
# 먹 - 어요오옹 (14) /  / not extracted
# 먹 - 어봐야겠다 (14) / [먹+어봐야겠다] /  extracted
# 먹 - 듯이 (14) / [먹+듯이] /  extracted
# 먹 - 어라고 (14) / [먹+어라고] /  extracted
# 먹 - 구있는데 (14) / [먹+구있는데] /  extracted
# 먹 - 어여어 (14) / [먹+어여어] /  extracted
# 먹 - 어쏭 (14) / [먹+어쏭] /  extracted
# 먹 - 는데에 (14) / [먹+는데에] /  extracted
# 먹 - 어주세요 (14) / [먹+어주세요] /  extracted
# 먹 - 는구야 (14) / [먹+는구야] /  extracted
# 먹 - 구싶다구 (14) /  / not extracted
# 먹 - 여살려야지 (14) /  / not extracted
# 먹 - 이기 (14) /  /  extracted
# 먹 - 어야겠따 (14) / [먹+어야겠따] /  extracted
# 먹 - 어야한대 (14) / [먹+어야한대] /  extracted
# 먹 - 으먼 (14) / [먹+으먼] /  extracted
# 먹 - 물 (14) /  / not extracted
# 먹 - 구올께 (14) /  / not extracted
# 먹 - 아 (14) / [먹+아] /  extracted
# 먹 - 구싶으면 (14) / [먹+구싶으면] /  extracted
# 먹 - 었뎌 (14) /  / not extracted
# 먹 - 는만큼 (14) / [먹+는만큼] /  extracted
# 먹 - 엇나요 (14) / [먹+엇나요] /  extracted
# 먹 - 구잇져 (14) / [먹+구잇져] /  extracted
# 먹 - 어보려고 (14) / [먹+어보려고] /  extracted
# 먹 - 질 (14) / [먹+질] /  extracted
# 먹 - 었어유 (14) / [먹+었어유] /  extracted
# 먹 - 여야징 (14) /  /  extracted
# 먹 - 어버림 (14) / [먹+어버림] /  extracted
# 먹 - 는동안 (14) / [먹+는동안] /  extracted
# 먹 - 어봐여 (14) / [먹+어봐여] /  extracted
# 먹 - 으려는 (14) / [먹+으려는] /  extracted
# 먹 - 어야겟넹 (14) / [먹+어야겟넹] /  extracted
# 먹 - 자해 (14) / [먹+자해] /  extracted
# 먹 - 어소 (13) / [먹+어소] /  extracted
# 먹 - 을고얌 (13) / [먹+을고얌] /  extracted
# 먹 - 기에 (13) / [먹+기에] /  extracted
# 먹 - 엇서요 (13) /  / not extracted
# 먹 - 구시푸 (13) / [먹+구시푸] /  extracted
# 먹 - 엇어유 (13) / [먹+엇어유] /  extracted
# 먹 - 어야되니까 (13) / [먹+어야되니까] /  extracted
# 먹 - 었나낭 (13) / [먹+었나낭] /  extracted
# 먹 - 어는 (13) / [먹+어는] /  extracted
# 먹 - 어줘요 (13) / [먹+어줘요] /  extracted
# 먹 - 었대요 (13) / [먹+었대요] /  extracted
# 먹 - 드라 (13) / [먹+드라] /  extracted
# 먹 - 어본지 (13) /  / not extracted
# 먹 - 을까했는데 (13) /  / not extracted
# 먹 - 었러 (13) / [먹+었러] /  extracted
# 먹 - 구왔엉 (13) /  / not extracted
# 먹 - 어야하눈데 (13) / [먹+어야하눈데] /  extracted
# 먹 - 었군요 (13) / [먹+었군요] /  extracted
# 먹 - 임 (13) /  / not extracted
# 먹 - 엄 (13) / [먹+엄] /  extracted
# 먹 - 습니당 (13) / [먹+습니당] /  extracted
# 먹 - 어야되는거 (13) / [먹+어야되는거] /  extracted
# 먹 - 여죠 (13) / [먹+여죠] /  extracted
# 먹 - 어얒 (13) / [먹+어얒] /  extracted
# 먹 - 었더라 (13) / [먹+었더라] /  extracted
# 먹 - 는다니깐 (13) /  / not extracted
# 먹 - 느냐 (13) / [먹+느냐] /  extracted
# 먹 - 었땅 (13) / [먹+었땅] /  extracted
# 먹 - 어야게써 (13) / [먹+어야게써] /  extracted
# 먹 - 구시픈데 (13) / [먹+구시픈데] /  extracted
# 먹 - 히지 (13) /  /  extracted
# 먹 - 쟛 (13) / [먹+쟛] /  extracted
# 먹 - 었다면서 (13) / [먹+었다면서] /  extracted
# 먹 - 겠는데 (13) / [먹+겠는데] /  extracted
# 먹 - 엇구만 (13) / [먹+엇구만] /  extracted
# 먹 - 엇겟다 (13) / [먹+엇겟다] /  extracted
# 먹 - 었나여 (13) / [먹+었나여] /  extracted
# 먹 - 으면대 (13) / [먹+으면대] /  extracted
# 먹 - 어야되는디 (13) / [먹+어야되는디] /  extracted
# 먹 - 구이썽 (13) / [먹+구이썽] /  extracted
# 먹 - 엇지만 (13) / [먹+엇지만] /  extracted
# 먹 - 엇떠 (13) / [먹+엇떠] /  extracted
# 먹 - 었지렁 (13) / [먹+었지렁] /  extracted
# 먹 - 는거래 (13) / [먹+는거래] /  extracted
# 먹 - 었쥐 (13) / [먹+었쥐] /  extracted
# 먹 - 어야해여 (13) / [먹+어야해여] /  extracted
# 먹 - 구있어여 (13) / [먹+구있어여] /  extracted
# 먹 - 구왔지 (13) /  / not extracted
# 먹 - 는다는거 (13) /  / not extracted
# 먹 - 자니깐 (13) /  / not extracted
# 먹 - 으려던 (12) / [먹+으려던] /  extracted
# 먹 - 어야제 (12) / [먹+어야제] /  extracted
# 먹 - 었다면 (12) / [먹+었다면] /  extracted
# 먹 - 어뜌 (12) / [먹+어뜌] /  extracted
# 먹 - 구있나 (12) /  / not extracted
# 먹 - 자그래서 (12) / [먹+자그래서] /  extracted
# 먹 - 으란 (12) / [먹+으란] /  extracted
# 먹 - 엇쩡 (12) /  / not extracted
# 먹 - 구서 (12) / [먹+구서] /  extracted
# 먹 - 어야할텐뎅 (12) / [먹+어야할텐뎅] /  extracted
# 먹 - 울고야 (12) /  /  extracted
# 먹 - 엇는대 (12) / [먹+엇는대] /  extracted
# 먹 - 겠지만 (12) / [먹+겠지만] /  extracted
# 먹 - 자궁 (12) / [먹+자궁] /  extracted
# 먹 - 으니가 (12) / [먹+으니가] /  extracted
# 먹 - 엇나용 (12) / [먹+엇나용] /  extracted
# 먹 - 구싶땅 (12) /  / not extracted
# 먹 - 으시오 (12) / [먹+으시오] /  extracted
# 먹 - 거랑 (12) /  / not extracted
# 먹 - 을라는데 (12) /  / not extracted
# 먹 - 었댜 (12) / [먹+었댜] /  extracted
# 먹 - 지말라면 (12) / [먹+지말라면] /  extracted
# 먹 - 어주께 (12) / [먹+어주께] /  extracted
# 먹 - 어야되고 (12) / [먹+어야되고] /  extracted
# 먹 - 은곳 (12) / [먹+은곳] /  extracted
# 먹 - 는다아아 (12) /  / not extracted
# 먹 - 겠습니당 (12) / [먹+겠습니당] /  extracted
# 먹 - 었쥬 (12) /  / not extracted
# 먹 - 쥐 (12) / [먹+쥐] /  extracted
# 먹 - 구가용 (12) /  / not extracted
# 먹 - 으려귱 (12) /  / not extracted
# 먹 - 었을듯 (12) / [먹+었을듯] /  extracted
# 먹 - 어쥬 (12) / [먹+어쥬] /  extracted
# 먹 - 을까하다가 (12) /  / not extracted
# 먹 - 는다아아앙 (12) /  / not extracted
# 먹 - 겅 (12) /  / not extracted
# 먹 - 으렁 (12) /  / not extracted
# 먹 - 어야짐 (12) / [먹+어야짐] /  extracted
# 먹 - 짱 (12) / [먹+짱] /  extracted
# 먹 - 여줭 (12) / [먹+여줭] /  extracted
# 먹 - 었쪄요 (12) /  / not extracted
# 먹 - 자아아 (12) /  / not extracted
# 먹 - 냐구 (12) / [먹+냐구] /  extracted
# 먹 - 으려니 (12) / [먹+으려니] /  extracted
# 먹 - 을려나 (12) / [먹+을려나] /  extracted
# 먹 - 이게 (12) / [먹+이게] /  extracted
# 먹 - 으몀 (12) / [먹+으몀] /  extracted
# 먹 - 은중 (12) /  / not extracted
# 먹 - 노 (12) / [먹+노] /  extracted
# 먹 - 구싶다아 (12) / [먹+구싶다아] /  extracted
# 먹 - 쨔 (12) /  / not extracted
# 먹 - 구올께용 (12) /  / not extracted
# 먹 - 구이땅 (12) / [먹+구이땅] /  extracted
# 먹 - 게따 (12) / [먹+게따] /  extracted
# 먹 - 으니깡 (12) / [먹+으니깡] /  extracted
# 먹 - 을고 (12) / [먹+을고] /  extracted
# 먹 - 어야하낭 (12) / [먹+어야하낭] /  extracted
# 먹 - 는거네 (11) / [먹+는거네] /  extracted
# 먹 - 기야 (11) /  / not extracted
# 먹 - 으랴고 (11) / [먹+으랴고] /  extracted
# 먹 - 어주라 (11) / [먹+어주라] /  extracted
# 먹 - 는거보면 (11) / [먹+는거보면] /  extracted
# 먹 - 었지여 (11) / [먹+었지여] /  extracted
# 먹 - 는담 (11) /  / not extracted
# 먹 - 어놔 (11) / [먹+어놔] /  extracted
# 먹 - 자앙 (11) / [먹+자앙] /  extracted
# 먹 - 아요 (11) / [먹+아요] /  extracted
# 먹 - 는다매 (11) /  / not extracted
# 먹 - 어야대나 (11) / [먹+어야대나] /  extracted
# 먹 - 어야되용 (11) /  / not extracted
# 먹 - 던징 (11) / [먹+던징] /  extracted
# 먹 - 되 (11) / [먹+되] /  extracted
# 먹 - 엇다니 (11) / [먹+엇다니] /  extracted
# 먹 - 지말걸 (11) / [먹+지말걸] /  extracted
# 먹 - 을겁니다 (11) /  / not extracted
# 먹 - 여요 (11) / [먹+여요] /  extracted
# 먹 - 지말라구 (11) / [먹+지말라구] /  extracted
# 먹 - 었겠넹 (11) / [먹+었겠넹] /  extracted
# 먹 - 넴 (11) /  / not extracted
# 먹 - 일라고 (11) /  /  extracted
# 먹 - 오야지 (11) / [먹+오야지] /  extracted
# 먹 - 여도 (11) / [먹+여도] /  extracted
# 먹 - 을겸 (11) /  / not extracted
# 먹 - 었쩡 (11) /  / not extracted
# 먹 - 었었나 (11) / [먹+었었나] /  extracted
# 먹 - 어러 (11) /  / not extracted
# 먹 - 구싶댜 (11) /  / not extracted
# 먹 - 었내 (11) /  / not extracted
# 먹 - 구싶지 (11) /  / not extracted
# 먹 - 냉 (11) /  / not extracted
# 먹 - 어야쥥 (11) / [먹+어야쥥] /  extracted
# 먹 - 겟지만 (11) / [먹+겟지만] /  extracted
# 먹 - 엇는데도 (11) / [먹+엇는데도] /  extracted
# 먹 - 엇던거 (11) / [먹+엇던거] /  extracted
# 먹 - 어보려구 (11) / [먹+어보려구] /  extracted
# 먹 - 디 (11) / [먹+디] /  extracted
# 먹 - 이가 (11) /  /  extracted
# 먹 - 여야하는데 (11) /  /  extracted
# 먹 - 자길래 (11) / [먹+자길래] /  extracted
# 먹 - 어부러 (11) /  / not extracted
# 먹 - 엇는디 (11) / [먹+엇는디] /  extracted
# 먹 - 던게 (11) / [먹+던게] /  extracted
# 먹 - 으면대지 (11) /  / not extracted
# 먹 - 구싶엉 (11) / [먹+구싶엉] /  extracted
# 먹 - 는꿈 (11) / [먹+는꿈] /  extracted
# 먹 - 는거냐 (11) / [먹+는거냐] /  extracted
# 먹 - 은건뎅 (11) / [먹+은건뎅] /  extracted
# 먹 - 는거나 (11) / [먹+는거나] /  extracted
# 먹 - 엇따 (11) / [먹+엇따] /  extracted
# 먹 - 어야할거같아 (11) / [먹+어야할거같아] /  extracted
# 먹 - 이네 (11) /  /  extracted
# 먹 - 엇눈뎅 (11) / [먹+엇눈뎅] /  extracted
# 먹 - 은건지 (11) / [먹+은건지] /  extracted
# 먹 - 일려고 (11) /  /  extracted
# 먹 - 구이쯍 (11) / [먹+구이쯍] /  extracted
# 먹 - 었나아 (11) / [먹+었나아] /  extracted
# 먹 - 구있지 (11) / [먹+구있지] /  extracted
# 먹 - 어야겟군 (11) / [먹+어야겟군] /  extracted
# 먹 - 겟군 (10) / [먹+겟군] /  extracted
# 먹 - 었습니까 (10) / [먹+었습니까] /  extracted
# 먹 - 여살려 (10) /  / not extracted
# 먹 - 힘 (10) / [먹+힘] /  extracted
# 먹 - 을까해 (10) /  / not extracted
# 먹 - 엇지이 (10) /  / not extracted
# 먹 - 기시름 (10) / [먹+기시름] /  extracted
# 먹 - 어야할까 (10) / [먹+어야할까] /  extracted
# 먹 - 으라면 (10) / [먹+으라면] /  extracted
# 먹 - 었아요 (10) / [먹+었아요] /  extracted
# 먹 - 어봤옹 (10) /  / not extracted
# 먹 - 어두됭 (10) / [먹+어두됭] /  extracted
# 먹 - 어쩌요 (10) /  / not extracted
# 먹 - 어야합니다 (10) / [먹+어야합니다] /  extracted
# 먹 - 겠구나 (10) / [먹+겠구나] /  extracted
# 먹 - 었는감 (10) / [먹+었는감] /  extracted
# 먹 - 엇구낭 (10) / [먹+엇구낭] /  extracted
# 먹 - 습니까 (10) / [먹+습니까] /  extracted
# 먹 - 을랩 (10) /  / not extracted
# 먹 - 어야지머 (10) /  / not extracted
# 먹 - 냐능 (10) / [먹+냐능] /  extracted
# 먹 - 을겜 (10) / [먹+을겜] /  extracted
# 먹 - 어씀 (10) / [먹+어씀] /  extracted
# 먹 - 을라꼬 (10) /  / not extracted
# 먹 - 어봤자 (10) / [먹+어봤자] /  extracted
# 먹 - 지말아야지 (10) / [먹+지말아야지] /  extracted
# 먹 - 는거같애 (10) / [먹+는거같애] /  extracted
# 먹 - 었다앙 (10) / [먹+었다앙] /  extracted
# 먹 - 더라구 (10) / [먹+더라구] /  extracted
# 먹 - 으려고해요 (10) /  / not extracted
# 먹 - 어야하니 (10) / [먹+어야하니] /  extracted
# 먹 - 기싫으면 (10) / [먹+기싫으면] /  extracted
# 먹 - 구왔오 (10) /  / not extracted
# 먹 - 겠농 (10) / [먹+겠농] /  extracted
# 먹 - 던뎅 (10) / [먹+던뎅] /  extracted
# 먹 - 지말아요 (10) / [먹+지말아요] /  extracted
# 먹 - 으려구영 (10) /  / not extracted
# 먹 - 겠네용 (10) / [먹+겠네용] /  extracted
# 먹 - 구해용 (10) /  / not extracted
# 먹 - 어옹 (10) / [먹+어옹] /  extracted
# 먹 - 는다궁 (10) /  / not extracted
# 먹 - 어야겟서 (10) / [먹+어야겟서] /  extracted
# 먹 - 겠오 (10) / [먹+겠오] /  extracted
# 먹 - 는지도 (10) / [먹+는지도] /  extracted
# 먹 - 겠네에 (10) / [먹+겠네에] /  extracted
# 먹 - 지맛 (10) / [먹+지맛] /  extracted
# 먹 - 나여 (10) / [먹+나여] /  extracted
# 먹 - 어떠니 (10) /  / not extracted
# 먹 - 을랴구 (10) /  / not extracted
# 먹 - 구있나요 (10) /  / not extracted
# 먹 - 어버렸다 (10) / [먹+어버렸다] /  extracted
# 먹 - 우까 (10) / [먹+우까] /  extracted
# 먹 - 어두되구 (10) / [먹+어두되구] /  extracted
# 먹 - 는거구나 (10) / [먹+는거구나] /  extracted
# 먹 - 었슴다 (10) / [먹+었슴다] /  extracted
# 먹 - 으라며 (10) /  / not extracted
# 먹 - 어야된다고 (10) / [먹+어야된다고] /  extracted
# 먹 - 여살릴 (10) /  / not extracted
# 먹 - 어봐도 (10) / [먹+어봐도] /  extracted
# 먹 - 어듀 (10) / [먹+어듀] /  extracted
# 먹 - 어보께 (10) / [먹+어보께] /  extracted
# 먹 - 어야하니깐 (9) / [먹+어야하니깐] /  extracted
# 먹 - 어야하는디 (9) / [먹+어야하는디] /  extracted
# 먹 - 었댜아 (9) / [먹+었댜아] /  extracted
# 먹 - 을텐뎅 (9) / [먹+을텐뎅] /  extracted
# 먹 - 는거잖아 (9) / [먹+는거잖아] /  extracted
# 먹 - 었기에 (9) / [먹+었기에] /  extracted
# 먹 - 구있쪄 (9) / [먹+구있쪄] /  extracted
# 먹 - 어야겠는데 (9) / [먹+어야겠는데] /  extracted
# 먹 - 구있나앙 (9) / [먹+구있나앙] /  extracted
# 먹 - 었겠당 (9) / [먹+었겠당] /  extracted
# 먹 - 우야지 (9) / [먹+우야지] /  extracted
# 먹 - 으라던데 (9) /  / not extracted
# 먹 - 지말규 (9) / [먹+지말규] /  extracted
# 먹 - 었담 (9) / [먹+었담] /  extracted
# 먹 - 업 (9) / [먹+업] /  extracted
# 먹 - 엇엇어 (9) / [먹+엇엇어] /  extracted
# 먹 - 어야한당 (9) /  / not extracted
# 먹 - 었능가 (9) /  / not extracted
# 먹 - 어보쟝 (9) /  / not extracted
# 먹 - 었는데두 (9) /  / not extracted
# 먹 - 구이써여 (9) / [먹+구이써여] /  extracted
# 먹 - 었엄 (9) /  / not extracted
# 먹 - 었어어 (9) / [먹+었어어] /  extracted
# 먹 - 기싫음 (9) / [먹+기싫음] /  extracted
# 먹 - 었다는데 (9) / [먹+었다는데] /  extracted
# 먹 - 는거보고 (9) / [먹+는거보고] /  extracted
# 먹 - 느라고 (9) / [먹+느라고] /  extracted
# 먹 - 어여징 (9) /  / not extracted
# 먹 - 었꽁 (9) /  / not extracted
# 먹 - 는거같아서 (9) / [먹+는거같아서] /  extracted
# 먹 - 나바 (9) / [먹+나바] /  extracted
# 먹 - 으나 (9) / [먹+으나] /  extracted
# 먹 - 었었지 (9) / [먹+었었지] /  extracted
# 먹 - 제용 (9) /  / not extracted
# 먹 - 느 (9) / [먹+느] /  extracted
# 먹 - 으소 (9) /  / not extracted
# 먹 - 었겠구나 (9) / [먹+었겠구나] /  extracted
# 먹 - 구팡 (9) / [먹+구팡] /  extracted
# 먹 - 는거니 (9) / [먹+는거니] /  extracted
# 먹 - 어떠용 (9) / [먹+어떠용] /  extracted
# 먹 - 을려구여 (9) /  / not extracted
# 먹 - 었어야했는데 (9) / [먹+었어야했는데] /  extracted
# 먹 - 었띵 (9) /  / not extracted
# 먹 - 엇뉘 (9) /  / not extracted
# 먹 - 인 (9) /  /  extracted
# 먹 - 어야해용 (9) / [먹+어야해용] /  extracted
# 먹 - 으라는거야 (9) /  / not extracted
# 먹 - 여야겠네 (9) /  /  extracted
# 먹 - 어리 (9) / [먹+어리] /  extracted
# 먹 - 어야한다고 (9) / [먹+어야한다고] /  extracted
# 먹 - 어쨔 (9) / [먹+어쨔] /  extracted
# 먹 - 었엎 (9) /  / not extracted
# 먹 - 더라고 (9) / [먹+더라고] /  extracted
# 먹 - 여줘야지 (9) /  /  extracted
# 먹 - 었어욥 (9) /  / not extracted
# 먹 - 으명 (9) / [먹+으명] /  extracted
# 먹 - 자나요 (9) / [먹+자나요] /  extracted
# 먹 - 었규 (9) /  / not extracted
# 먹 - 겠 (9) / [먹+겠] /  extracted
# 먹 - 는거보단 (9) / [먹+는거보단] /  extracted
# 먹 - 어줌 (9) / [먹+어줌] /  extracted
# 먹 - 었뉴 (9) /  / not extracted
# 먹 - 여주셔서 (9) /  /  extracted
# 먹 - 쟁 (9) / [먹+쟁] /  extracted
# 먹 - 오오 (9) /  / not extracted
# 먹 - 으룜 (9) /  / not extracted
# 먹 - 어야한다용 (9) / [먹+어야한다용] /  extracted
# 먹 - 았는데 (8) / [먹+았는데] /  extracted
# 먹 - 으라거 (8) /  / not extracted
# 먹 - 엇더여 (8) /  / not extracted
# 먹 - 구왔다 (8) /  / not extracted
# 먹 - 어주기 (8) / [먹+어주기] /  extracted
# 먹 - 어효 (8) /  / not extracted
# 먹 - 구이써요 (8) /  / not extracted
# 먹 - 어짜나 (8) / [먹+어짜나] /  extracted
# 먹 - 는사진 (8) / [먹+는사진] /  extracted
# 먹 - 었다니깐 (8) / [먹+었다니깐] /  extracted
# 먹 - 을란다 (8) /  / not extracted
# 먹 - 을복 (8) /  / not extracted
# 먹 - 어가요 (8) / [먹+어가요] /  extracted
# 먹 - 댜 (8) / [먹+댜] /  extracted
# 먹 - 었능데 (8) / [먹+었능데] /  extracted
# 먹 - 어가용 (8) / [먹+어가용] /  extracted
# 먹 - 구잇죠 (8) / [먹+구잇죠] /  extracted
# 먹 - 구이쪙 (8) / [먹+구이쪙] /  extracted
# 먹 - 나보넹 (8) / [먹+나보넹] /  extracted
# 먹 - 는얘기 (8) /  / not extracted
# 먹 - 자능 (8) / [먹+자능] /  extracted
# 먹 - 구웅 (8) / [먹+구웅] /  extracted
# 먹 - 어야뎅 (8) /  / not extracted
# 먹 - 나봥 (8) / [먹+나봥] /  extracted
# 먹 - 어버린다 (8) / [먹+어버린다] /  extracted
# 먹 - 을기회가 (8) /  / not extracted
# 먹 - 도 (8) / [먹+도] /  extracted
# 먹 - 을까해요 (8) /  / not extracted
# 먹 - 을게영 (8) /  / not extracted
# 먹 - 어연 (8) /  / not extracted
# 먹 - 어도됭 (8) / [먹+어도됭] /  extracted
# 먹 - 었됴 (8) / [먹+었됴] /  extracted
# 먹 - 어야되잖아 (8) /  / not extracted
# 먹 - 엇나바 (8) / [먹+엇나바] /  extracted
# 먹 - 을까해서 (8) /  / not extracted
# 먹 - 어본게 (8) /  / not extracted
# 먹 - 구잇는데 (8) / [먹+구잇는데] /  extracted
# 먹 - 으라규 (8) /  / not extracted
# 먹 - 었나욤 (8) /  / not extracted
# 먹 - 을게없당 (8) /  / not extracted
# 먹 - 는구 (8) / [먹+는구] /  extracted
# 먹 - 으라공 (8) /  / not extracted
# 먹 - 여살리려면 (8) /  / not extracted
# 먹 - 어봐야겠당 (8) / [먹+어봐야겠당] /  extracted
# 먹 - 억어 (8) / [먹+억어] /  extracted
# 먹 - 구이따 (8) / [먹+구이따] /  extracted
# 먹 - 을게없는데 (7) /  / not extracted
# 먹 - 을겅 (7) /  / not extracted
# 먹 - 었대서 (7) / [먹+었대서] /  extracted
# 먹 - 는고얌 (7) / [먹+는고얌] /  extracted
# 먹 - 을깜 (7) / [먹+을깜] /  extracted
# 먹 - 기싫어도 (7) /  / not extracted
# 먹 - 었다냥 (7) / [먹+었다냥] /  extracted
# 먹 - 었더요 (7) /  / not extracted
# 먹 - 어야도 (7) / [먹+어야도] /  extracted
# 먹 - 는줄알고 (7) / [먹+는줄알고] /  extracted
# 먹 - 구갈래 (7) /  / not extracted
# 먹 - 으게 (7) /  / not extracted
# 먹 - 죵 (7) / [먹+죵] /  extracted
# 먹 - 을동안 (7) / [먹+을동안] /  extracted
# 먹 - 엇데 (7) / [먹+엇데] /  extracted
# 먹 - 었댱 (7) /  / not extracted
# 먹 - 었댜앗 (7) /  / not extracted
# 먹 - 겠다구 (7) / [먹+겠다구] /  extracted
# 먹 - 겠다아 (7) / [먹+겠다아] /  extracted
# 먹 - 지않는다 (7) / [먹+지않는다] /  extracted
# 먹 - 게찌 (7) / [먹+게찌] /  extracted
# 먹 - 는다묘 (7) /  / not extracted
# 먹 - 어꾸 (7) / [먹+어꾸] /  extracted
# 먹 - 엏 (7) /  / not extracted
# 먹 - 어보는 (7) / [먹+어보는] /  extracted
# 먹 - 앙 (7) / [먹+앙] /  extracted
# 먹 - 었나보넹 (6) / [먹+었나보넹] /  extracted
# 먹 - 자공 (6) / [먹+자공] /  extracted
# 먹 - 는군요 (6) / [먹+는군요] /  extracted
# 먹 - 을게없어요 (6) /  / not extracted
# 먹 - 으겡 (6) /  / not extracted
# 먹 - 이는거 (6) /  /  extracted
# 먹 - 구잇도 (6) /  / not extracted
# 먹 - 구시퐁 (6) /  / not extracted
# 먹 - 얶어 (6) / [먹+얶어] /  extracted
# 먹 - 었을땐 (6) / [먹+었을땐] /  extracted
# 먹 - 는거같은데 (6) / [먹+는거같은데] /  extracted
# 먹 - 울까 (6) / [먹+울까] /  extracted
# 먹 - 었딩 (6) /  / not extracted
# 먹 - 으야지 (6) / [먹+으야지] /  extracted
# 먹 - 는거가 (6) / [먹+는거가] /  extracted
# 먹 - 으라하면 (6) /  / not extracted
# 먹 - 는밥 (6) /  / not extracted
# 먹 - 어보겠어 (6) / [먹+어보겠어] /  extracted
# 먹 - 어뇨 (6) /  / not extracted
# 먹 - 어이 (6) / [먹+어이] /  extracted
# 먹 - 었제 (6) / [먹+었제] /  extracted
# 먹 - 었네여 (6) / [먹+었네여] /  extracted
# 먹 - 을깨 (6) /  / not extracted
# 먹 - 지않았어 (6) / [먹+지않았어] /  extracted
# 먹 - 었다는게 (6) / [먹+었다는게] /  extracted
# 먹 - 눈중 (6) / [먹+눈중] /  extracted
# 먹 - 우께 (6) / [먹+우께] /  extracted
# 먹 - 어버릴거야 (6) / [먹+어버릴거야] /  extracted
# 먹 - 는정도 (6) / [먹+는정도] /  extracted
# 먹 - 어봣어요 (6) / [먹+어봣어요] /  extracted
# 먹 - 자넹 (6) / [먹+자넹] /  extracted
# 먹 - 어버렸네 (6) / [먹+어버렸네] /  extracted
# 먹 - 구있징 (6) / [먹+구있징] /  extracted
# 먹 - 자하지 (6) /  / not extracted
# 먹 - 킷리스트 (6) /  / not extracted
# 먹 - 었어야하는데 (6) /  / not extracted
# 먹 - 는구먼 (6) / [먹+는구먼] /  extracted
# 먹 - 는다네 (6) /  / not extracted
# 먹 - 으랴궁 (6) /  / not extracted
# 먹 - 으라네 (6) /  / not extracted
# 먹 - 어줄겡 (6) / [먹+어줄겡] /  extracted
# 먹 - 어보아요 (6) / [먹+어보아요] /  extracted
# 먹 - 었을걸 (6) / [먹+었을걸] /  extracted
# 먹 - 이니까 (6) /  /  extracted
# 먹 - 었냉 (6) /  / not extracted
# 먹 - 구시펑 (6) /  / not extracted
# 먹 - 었을까요 (6) /  / not extracted
# 먹 - 었썽 (6) / [먹+었썽] /  extracted
# 먹 - 여줄 (6) /  /  extracted
# 먹 - 었다오 (6) /  / not extracted
# 먹 - 어봤징 (6) /  / not extracted
# 먹 - 었을라나 (6) /  / not extracted
# 먹 - 으려니까 (6) / [먹+으려니까] /  extracted
# 먹 - 응 (6) /  / not extracted
# 먹 - 었노 (6) / [먹+었노] /  extracted
# 먹 - 여야딩 (6) /  /  extracted
# 먹 - 어주 (6) / [먹+어주] /  extracted
# 먹 - 엇는뎀 (6) /  / not extracted
# 먹 - 거든요 (6) / [먹+거든요] /  extracted
# 먹 - 자잉 (6) / [먹+자잉] /  extracted
# 먹 - 으야징 (6) /  / not extracted
# 먹 - 히네 (6) /  /  extracted
# 먹 - 게됨 (6) / [먹+게됨] /  extracted
# 먹 - 엇어야지 (6) / [먹+엇어야지] /  extracted
# 먹 - 었나보군 (6) /  / not extracted
# 먹 - 어도됑 (6) /  / not extracted
# 먹 - 는다규 (6) /  / not extracted
# 먹 - 을게염 (6) /  / not extracted
# 먹 - 었다공 (6) /  / not extracted
# 먹 - 었다아아 (6) / [먹+었다아아] /  extracted
# 먹 - 는거디 (6) / [먹+는거디] /  extracted
# 먹 - 여야하나 (6) /  /  extracted
# 먹 - 구가면 (6) / [먹+구가면] /  extracted
# 먹 - 어자기 (6) /  / not extracted
# 먹 - 으까앙 (6) /  / not extracted
# 먹 - 는거구 (6) / [먹+는거구] /  extracted
# 먹 - 는데는 (6) / [먹+는데는] /  extracted
# 먹 - 구해요 (6) /  / not extracted
# 먹 - 겟습니다 (6) / [먹+겟습니다] /  extracted
# 먹 - 는다고는 (6) /  / not extracted
# 먹 - 일걸 (6) /  / not extracted
# 먹 - 나아 (6) / [먹+나아] /  extracted
# 먹 - 는다는걸 (6) /  / not extracted
# 먹 - 자규 (6) / [먹+자규] /  extracted
# 먹 - 어쭁 (6) /  / not extracted
# 먹 - 었지요오 (6) /  / not extracted
# 먹 - 엇군 (6) / [먹+엇군] /  extracted
# 먹 - 어야될텐데 (6) /  / not extracted
# 먹 - 자그럼 (6) / [먹+자그럼] /  extracted
# 먹 - 구싶땽 (2) /  / not extracted
# 먹 - 기싫어져서 (2) /  / not extracted
# 먹 - 거랏 (2) / [먹+거랏] / not extracted
# 먹 - 어조야됭 (2) /  / not extracted
# 먹 - 는거였대 (2) /  / not extracted
# 먹 - 지않음 (2) / [먹+지않음] / not extracted
# 먹 - 구싶다거나 (2) /  / not extracted

# %%
l = '갈'
for r, count in chat_predicator_extractor.lrgraph.get_r(l, topk=-1):
    word = l + r    
    word_is_extracted = word in chat_predicators

    is_stem = lambda x: x in chat_predicator_extractor._stems
    is_eomi = lambda x: x in chat_predicator_extractor._eomis
    lemmas = _lemma_candidate(l, r)
    lemmas = {(stem, eomi) for stem, eomi in lemmas
              if is_stem(stem) and is_eomi(eomi)}
    lemmas_strf = '' if not lemmas else '[%s]' % ', '.join('%s+%s'%lr for lr in lemmas)

    print('{} - {} ({}) / {} / {}extracted'.format(
        l, r, count, lemmas_strf, ' ' if word_is_extracted else 'not '))
# Out:
# 갈 - 게 (6120) / [갈+게, 가+ㄹ게] /  extracted
# 갈 - 게요 (1852) / [갈+게요, 가+ㄹ게요] /  extracted
# 갈 - 겡 (1219) / [갈+겡, 가+ㄹ겡] /  extracted
# 갈 - 게용 (710) / [가+ㄹ게용, 갈+게용] /  extracted
# 갈 - 려고 (660) / [가+ㄹ려고, 갈+려고] /  extracted
# 갈 - 지 (525) / [가+ㄹ지, 갈+지] /  extracted
# 갈 - 라구 (515) / [가+ㄹ라구, 갈+라구, 가르+아구] /  extracted
# 갈 - 거 (431) /  / not extracted
# 갈 - 려구 (413) / [가+ㄹ려구, 갈+려구] /  extracted
# 갈 - 랭 (366) / [갈+랭, 가+ㄹ랭] /  extracted
# 갈 - 게여 (301) / [갈+게여, 가+ㄹ게여] /  extracted
# 갈 - 거같아 (298) / [갈+거같아, 가+ㄹ거같아] /  extracted
# 갈 - 깡 (263) / [가+ㄹ깡, 갈+깡] /  extracted
# 갈 - 껭 (257) / [갈+껭, 가+ㄹ껭] /  extracted
# 갈 - 라궁 (206) / [가+ㄹ라궁, 가르+아궁, 갈+라궁] /  extracted
# 갈 - 테니까 (201) / [가+ㄹ테니까, 갈+테니까] /  extracted
# 갈 - 거면 (184) / [갈+거면, 가+ㄹ거면] /  extracted
# 갈 - 거얌 (175) / [가+ㄹ거얌, 갈+거얌] /  extracted
# 갈 - 려면 (154) / [가+ㄹ려면, 갈+려면] /  extracted
# 갈 - 텐데 (153) / [가+ㄹ텐데, 갈+텐데] /  extracted
# 갈 - 지도 (152) / [가+ㄹ지도, 갈+지도] /  extracted
# 갈 - 땐 (147) / [가+ㄹ땐, 갈+땐] /  extracted
# 갈 - 아입구 (143) /  /  extracted
# 갈 - 거양 (140) / [갈+거양, 가+ㄹ거양] /  extracted
# 갈 - 거임 (124) / [가+ㄹ거임, 갈+거임] /  extracted
# 갈 - 려궁 (121) / [갈+려궁, 가+ㄹ려궁] /  extracted
# 갈 - 라면 (121) / [가르+아면, 가+ㄹ라면, 갈+라면] /  extracted
# 갈 - 려햇는데 (15) / [가+ㄹ려햇는데, 갈+려햇는데] /  extracted
# 갈 - 겸 (15) / [가+ㄹ겸, 갈+겸] /  extracted
# 갈 - 아타야징 (15) /  / not extracted
# 갈 - 라그랬는데 (14) / [가+ㄹ라그랬는데, 갈+라그랬는데, 가르+아그랬는데] /  extracted
# 갈 - 거면서 (14) / [가+ㄹ거면서, 갈+거면서] /  extracted
# 갈 - 줄알고 (14) / [가+ㄹ줄알고, 갈+줄알고] /  extracted
# 갈 - 게오 (14) / [갈+게오, 가+ㄹ게오] /  extracted
# 갈 - 켜줘 (14) /  /  extracted
# 갈 - 지안갈지도 (14) /  / not extracted
# 갈 - 거지요 (14) /  / not extracted
# 갈 - 라지고 (14) / [가르+아지고] /  extracted
# 갈 - 따 (13) /  / not extracted
# 갈 - 라꼬 (13) / [가르+아꼬, 갈+라꼬, 가+ㄹ라꼬] /  extracted
# 갈 - 궈야지 (13) /  / not extracted
# 갈 - 아입을게 (13) /  /  extracted
# 갈 - 게요오 (13) / [갈+게요오, 가+ㄹ게요오] /  extracted
# 갈 - 줄은 (13) / [가+ㄹ줄은, 갈+줄은] /  extracted
# 갈 - 랩 (13) / [가+ㄹ랩, 갈+랩] /  extracted
# 갈 - 랴고 (13) / [가+ㄹ랴고, 갈+랴고] /  extracted
# 갈 - 라진 (13) / [가르+아진] /  extracted
# 갈 - 거얀 (13) /  / not extracted
# 갈 - 거징 (13) /  / not extracted
# 갈 - 려서 (13) / [가+ㄹ려서, 갈+려서] /  extracted
# 갈 - 라햇지 (13) / [갈+라햇지, 가+ㄹ라햇지, 가르+아햇지] /  extracted
# 갈 - 순 (13) /  / not extracted
# 갈 - 거요 (13) /  / not extracted
# 갈 - 아야지 (12) / [가+ㄹ아야지, 갈+아야지] /  extracted
# 갈 - 꾸다 (12) / [가+ㄹ꾸다, 갈+꾸다] /  extracted
# 갈 - 아타성 (12) /  / not extracted
# 갈 - 아입으러 (12) /  /  extracted
# 갈 - 끼 (12) /  / not extracted
# 갈 - 거같오 (12) / [갈+거같오, 가+ㄹ거같오] /  extracted
# 갈 - 거얏 (12) /  / not extracted
# 갈 - 아야겠다 (11) / [가+ㄹ아야겠다, 갈+아야겠다] /  extracted
# 갈 - 려는데 (11) / [가+ㄹ려는데, 갈+려는데] /  extracted
# 갈 - 아타야 (11) /  / not extracted
# 갈 - 아입었는데 (11) /  /  extracted
# 갈 - 테다 (11) /  / not extracted
# 갈 - 아탈까 (11) /  / not extracted
# 갈 - 거같다 (11) / [갈+거같다, 가+ㄹ거같다] /  extracted
# 갈 - 거예용 (11) /  / not extracted
# 갈 - 라귱 (11) / [가+ㄹ라귱, 갈+라귱, 가르+아귱] /  extracted
# 갈 - 아입기 (11) /  /  extracted
# 갈 - 아입지 (11) /  /  extracted
# 갈 - 건디 (11) / [가+ㄹ건디, 갈+건디] /  extracted
# 갈 - 꼰데 (10) / [가+ㄹ꼰데, 갈+꼰데] /  extracted
# 갈 - 거지만 (10) / [가+ㄹ거지만, 갈+거지만] /  extracted
# 갈 - 게여어 (10) / [갈+게여어, 가+ㄹ게여어] /  extracted
# 갈 - 랬는뎅 (10) / [갈+랬는뎅, 가+ㄹ랬는뎅] /  extracted
# 갈 - 거죠 (10) /  / not extracted
# 갈 - 랬더니 (10) / [갈+랬더니, 가+ㄹ랬더니] /  extracted
# 갈 - 뤠 (10) / [가+ㄹ뤠, 갈+뤠] /  extracted
# 갈 - 건 (10) / [가+ㄹ건, 갈+건] /  extracted
# 갈 - 아타야대 (10) /  / not extracted
# 갈 - 아타지 (10) /  / not extracted
# 갈 - 쳐줘 (10) / [갈+쳐줘, 가+ㄹ쳐줘] /  extracted
# 갈 - 기가 (10) / [갈+기가, 가+ㄹ기가] /  extracted
# 갈 - 게엥 (10) / [가+ㄹ게엥, 갈+게엥] /  extracted
# 갈 - 아탈거야 (10) /  / not extracted
# 갈 - 아입을옷 (10) /  / not extracted
# 갈 - 거같아여 (10) / [가+ㄹ거같아여, 갈+거같아여] /  extracted
# 갈 - 지를 (10) / [갈+지를] /  extracted
# 갈 - 건가요 (10) /  / not extracted
# 갈 - 아입었어요 (10) /  /  extracted
# 갈 - 아도 (10) / [가+ㄹ아도, 갈+아도] /  extracted
# 갈 - 동안 (10) /  / not extracted
# 갈 - 건대 (10) / [갈+건대, 가+ㄹ건대] /  extracted
# 갈 - 아타야행 (9) /  / not extracted
# 갈 - 린다 (9) / [가+ㄹ린다, 갈+린다] /  extracted
# 갈 - 껩 (9) / [가+ㄹ껩, 갈+껩] /  extracted
# 갈 - 려구여 (9) / [갈+려구여, 가+ㄹ려구여] /  extracted
# 갈 - 기 (9) / [가+ㄹ기, 갈+기] /  extracted
# 갈 - 줄알았는데 (9) / [갈+줄알았는데, 가+ㄹ줄알았는데] /  extracted
# 갈 - 라그랫는데 (9) / [가르+아그랫는데, 갈+라그랫는데, 가+ㄹ라그랫는데] /  extracted
# 갈 - 아탔어용 (9) /  / not extracted
# 갈 - 아탈게 (9) /  / not extracted
# 갈 - 거같당 (9) / [갈+거같당, 가+ㄹ거같당] /  extracted
# 갈 - 아입어서 (9) /  /  extracted
# 갈 - 아탔다 (9) /  / not extracted
# 갈 - 아입을까 (9) /  /  extracted
# 갈 - 아먹고 (9) / [갈+아먹고, 가+ㄹ아먹고] /  extracted
# 갈 - 둣 (9) / [갈+둣, 가+ㄹ둣] /  extracted
# 갈 - 태니까 (9) / [갈+태니까, 가+ㄹ태니까] /  extracted
# 갈 - 아탈라고 (9) /  / not extracted
# 갈 - 다가 (9) / [갈+다가, 가+ㄹ다가] /  extracted
# 갈 - 궈서 (9) /  / not extracted
# 갈 - 았는데 (8) / [갈+았는데, 가+ㄹ았는데] /  extracted
# 갈 - 거지롱 (8) /  / not extracted
# 갈 - 아신고 (8) /  / not extracted
# 갈 - 겐 (8) /  / not extracted
# 갈 - 랫 (8) / [갈+랫, 가+ㄹ랫] /  extracted
# 갈 - 려고용 (8) / [가+ㄹ려고용, 갈+려고용] /  extracted
# 갈 - 궹 (6) / [가+ㄹ궹, 갈+궹] /  extracted
# 갈 - 껀 (6) / [갈+껀, 가+ㄹ껀] /  extracted
# 갈 - 아입을꺼 (6) /  /  extracted
# 갈 - 곤데 (6) /  / not extracted
# 갈 - 라서 (6) / [가+ㄹ라서, 갈+라서, 가르+아서] /  extracted
# 갈 - 러 (6) / [가르+어, 갈+러] /  extracted
# 갈 - 게갈게 (6) /  / not extracted
# 갈 - 아타야겠다 (6) /  / not extracted
# 갈 - 테고 (6) / [갈+테고, 가+ㄹ테고] /  extracted
# 갈 - 아타쩌 (6) /  / not extracted
# 갈 - 꼬지 (6) /  / not extracted
# 갈 - 랫지 (6) / [갈+랫지, 가+ㄹ랫지] /  extracted
# 갈 - 궜어 (6) /  / not extracted
# 갈 - 아야 (6) / [갈+아야, 가+ㄹ아야] /  extracted
# 갈 - 끈데 (6) / [갈+끈데, 가+ㄹ끈데] /  extracted
# 갈 - 아끼우고 (6) /  / not extracted
# 갈 - 끼다 (6) / [갈+끼다, 가+ㄹ끼다] /  extracted
# 갈 - 아입 (6) /  / not extracted
# 갈 - 꽈 (6) / [갈+꽈, 가+ㄹ꽈] /  extracted
# 갈 - 껍니당 (6) /  / not extracted
# 갈 - 거같은 (6) /  / not extracted
# 갈 - 거가튼데 (6) /  / not extracted
# 갈 - 어 (6) / [갈+어, 가+ㄹ어] /  extracted
# 갈 - 력 (6) /  / not extracted
# 갈 - 지만 (6) / [갈+지만, 가+ㄹ지만] /  extracted
# 갈 - 렸어 (6) /  / not extracted
# 갈 - 게얌 (6) /  / not extracted
# 갈 - 아입엉 (6) /  /  extracted
# 갈 - 껑 (6) /  / not extracted
# 갈 - 려요 (6) / [가+ㄹ려요, 갈+려요] /  extracted
# 갈 - 도 (6) / [갈+도, 가+ㄹ도] /  extracted
# 갈 - 아탔엉 (6) /  / not extracted
# 갈 - 껀디 (5) /  / not extracted
# 갈 - 켜줄게 (5) /  / not extracted
# 갈 - 아줌 (5) / [갈+아줌] / not extracted
# 갈 - 거같긴 (5) /  / not extracted
# 갈 - 아탓당 (5) /  / not extracted
# 갈 - 삘 (5) / [가+ㄹ삘] / not extracted
# 갈 - 듭 (5) / [가+ㄹ듭, 갈+듭] / not extracted
# 갈 - 깜 (5) /  / not extracted
# 갈 - 아타기전에 (5) /  / not extracted
# 갈 - 라우 (5) / [갈+라우, 가+ㄹ라우] / not extracted
# 갈 - 거같습니다 (5) /  / not extracted
# 갈 - 아입공 (5) /  / not extracted
# 갈 - 아타영 (5) /  / not extracted
# 갈 - 긋 (5) /  / not extracted
# 갈 - 아타래 (5) /  / not extracted
# 갈 - 꼬예용 (5) /  / not extracted
# 갈 - 아입는게 (5) /  / not extracted
# 갈 - 아타따 (5) /  / not extracted
# 갈 - 아입어야겠다 (5) /  / not extracted
# 갈 - 거같네 (5) / [가+ㄹ거같네] / not extracted
# 갈 - 확률이 (5) / [가+ㄹ확률이] / not extracted
# 갈 - 아입는 (5) /  / not extracted
